# %% [raw]
# ---
# title: "Other Home-Based Trip Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
from pathlib import Path
import util
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
# %store -r validation_data

# config = validation_data.config.copy()
# trip = validation_data.trip.copy()
# hh = validation_data.hh.copy()
# person = validation_data.person.copy()
# df_parcel = validation_data.land_use.copy()

config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'trip'])

hh = data.hh.to_pandas()
person = data.person.to_pandas()
trip = data.trip.to_pandas()
# df_parcel = data.land_use.to_pandas()

# %%
df_trip = trip.copy()
df_hh = hh.copy()
df_person = person.copy()

# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_count_worker'] = df_hh['hhvehs']-df_hh['hhwkrs']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

df_hh['auto_available_worker'] = np.where(df_hh['hhwkrs']<=0, "no worker",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_worker']<0, "cars fewer than workers", "enough cars")))


# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: transit",
            8: "8: school bus",
            9: "9: tnc"}
df_trip['mode_label'] = df_trip['mode'].map(mode_cat)

dpurp_cat = {1: "Work",
              2: "School",
              3: "Escort",
              4: "Personal Business",
              5: "Shop",
              6: "Meal",
              7: "Social"}
df_trip['dpurp_label'] = df_trip['dpurp'].map(dpurp_cat)

# df_hh = df_hh.merge(df_parcel,how="left",left_on='hhno',right_on='parcelid')
df_person = df_person.merge(df_hh,
                          how='left', on=['hhno','source']) # get auto ownership from hh data

df_trip = df_trip.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
hb_trip = df_trip.loc[~(df_trip['dpurp'].isin([1,2,3]))].copy()

# %%
df_plot = hb_trip.groupby(['source','mode_label'])['trexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['trexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = hb_trip.groupby(['source','mode_label'])['trexpfac'].count().reset_index(). \
    rename(columns={'trexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','mode_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="mode_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="other home-based trip mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="bc624721-f8b7-47b6-b953-7a87f69ac93b" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bc624721-f8b7-47b6-b953-7a87f69ac93b")) {                    Plotly.newPlot(                        "bc624721-f8b7-47b6-b953-7a87f69ac93b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xX0hAFhvAwCTRl0Amu8yAJHsHgA\u002fEQMA1KICABqZAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"z8aCf9pHxD+RQFt17ReRP5tXexBYYNs\u002fGHXk24bQzD8I9CCCf1TBP3E8rK6+6JY\u002fzCc9hn6+hj\u002fXrhcnZZxpPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"lhRVAgwi1g+vB\u002fwDjwBcAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003emode_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"b5Kehus4wD\u002fdfhNGQNOLP\u002f702H8g6Nw\u002fCDajZSCuyz9rdMi7kjfCPwMFgvJ2GqE\u002fbYdLP63lhz\u002fk76xpeN5xPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.555555555 ...

# %%
df_plot = hb_trip.groupby(['source','dpurp_label','mode_label'])['trexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source','dpurp_label'], group_keys=False)['trexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = hb_trip.groupby(['source','dpurp_label','mode_label'])['trexpfac'].count().reset_index(). \
    rename(columns={'trexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','dpurp_label','mode_label'])

fig = px.bar(df_plot.sort_values(['source','mode_label']),
             x="percentage", y="mode_label", color="source",barmode="group",
             facet_col='dpurp_label', facet_col_wrap=1, orientation='h',
             hover_data=['sample count'],
             category_orders={"mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                               "8: school bus","9: other–survey only"]},
             title="other home-based trip mode choice")
fig.update_layout(height=1000, width=650)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="994649f1-852c-4250-be5c-642bfe300748" class="plotly-graph-div" style="height:1000px; width:650px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("994649f1-852c-4250-be5c-642bfe300748")) {                    Plotly.newPlot(                        "994649f1-852c-4250-be5c-642bfe300748",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"3s8CAJMyAACTVQcAcP4EAHOVAgBpPgAAgREAALoKAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003edpurp_label=Meal\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"qEBfl32OxT9nCQCuyCCIPxEpCmIDiNk\u002f6u\u002fDmwKc0D+2NFHB3gvBP3MSR5CsmpY\u002fo0oJuyN1bD\u002fMJpT3P5hlPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"RPYBAOkuAADWBwgAU+UDALviAQDVRQAAygUAAMESAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003edpurp_label=Personal Business\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"WwpkCVlEwD9TT8EYmSSIPwSi91VzOd8\u002fv9s66RdOzT9VsVZUdHO8P9olu6\u002fvDJw\u002fvEE\u002fC4ezVD+En5A19HNyPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"wgMFAPp2AADXAhMAu50JAJqDBAAkdwAAVBQAAIcXAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003edpurp_label=Shop\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"YOG\u002fcLaowT9O9KebWLaJPx6qpqrpz94\u002fQDzpkSsQzj8MzwzV+hK8P6Hb\u002fnNZkpM\u002fbWY\u002fUBdIXz\u002feRROqFWNkPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"1PgIAKzOAABRtw4AhkQJAA5ABQCCXwAA7CoAAO8WAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003edpurp_label=Social\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"SvsprWuUzD9deF0WM\u002fqVP\u002ffpN+T5+tc\u002f8fzDa3tKzT\u002fZE5j8KIjAPwPA7OJLi5A\u002f6XnWAVgscD9cSYm0YDpkPw=="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"GwIuAIECzQHdAEAAAQAGAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003edpurp_label=Meal\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E" ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### person type

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['trexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'mode_label'])['trexpfac'].count().reset_index(). \
        rename(columns={'trexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'mode_label'])

    fig = px.bar(df_plot.sort_values(['mode_label']),
                 x="percentage", y="mode_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="other home-based trip mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
plot_mode_choice(hb_trip,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: other–survey only"]},
                 "person type",2,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="720217ea-a996-4808-89d7-8e0b61e453bf" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("720217ea-a996-4808-89d7-8e0b61e453bf")) {                    Plotly.newPlot(                        "720217ea-a996-4808-89d7-8e0b61e453bf",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"PnoLABdCAQDa5isA06oNAL\u002fhBwAnGAEAAQAAAO45AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"vPSCje73wz\u002ftcrvOth2SPyLBHQ76XeE\u002fTygqXHsxxT99qDRTpvW3P9CEwmguGZU\u002fsZAoxjIebT4IB0A2Zj9vPw=="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"1QX7ABsKZgOeARYBHgA=","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"Cii44zJJvz98gdh6spiTP9SxUuhnsOE\u002fUSJfkbq4xz9pUFMWts26P4zdCO+en4s\u002fTQcvgURIYz8="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"MiYDAHhNAADH9QoApwcEABxTAgAKNgAAyAwAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"BKVrevi0wz\u002ff6wbsjdmOP9gDCys1dOA\u002fO\u002frSUEQ9yD9ofVjAwNC7P7WrPus1YpA\u002fnp8zEKOrZj8="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"GAEnALwCAwFwAE0ABgA=","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"9tnocxdHuD\u002fmu8unjrp7P57GzxT7ft8\u002fydmJywK\u002f0T\u002fomX9t0TW3P\u002fCPskLVRqM\u002fw2KDrQgGRj8="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","9: tnc"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"sYQFAPlXAADkrg8AZnQIADdrAgAFnAAABTIAAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=non-worker age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h"," ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(hb_trip,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: other–survey only"]},
                 "household size",2,600)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="bc759b2f-4877-47f9-b713-694554850e09" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bc759b2f-4877-47f9-b713-694554850e09")) {                    Plotly.newPlot(                        "bc759b2f-4877-47f9-b713-694554850e09",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"W5EGAH58AADK7A8AtvIBADGPAABb1gAAAwAAAENEAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"w5Wc6gg20T9S3kj\u002fuiOUP96yctaXKOI\u002fsRhZ+ydqsT9PQ4yywaGUP+pubHuiW6c\u002fHSQuBKPjzz7niGupK8yEPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"3QSJAFYH8wBIAGwBAQAYAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"dCmFDYENyj89UM5kMGmDP5HihKEQJ+I\u002fyA\u002flzpDRtT8zg0Qo5qaeP0ZIp+rUb7k\u002feAn6GAcJIT9riq1Q8Lp0Pw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"D88JAEbdAACPfiEAQ8gOAKCDAQD61gAAjBYAAFgqAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"KIUZkoagxT9Z5emF2TOQP0UkNwqfAeE\u002fMf6KYB24zT+TfvYdzxyZP5tmbs8UE5c\u002fylpi0qxGVT+dYhMct3ZqPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"mgSlAIEJ+QUPAckABwAWAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"PF8KpxglwD8L8L8zZ2mGP5pqR46NrOA\u002fcf3Z9SVqzj8qPpnzekuyP1+hPXbUbZk\u002fXMLlOtE\u002fZD+d80EorW92Pw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"B6MFAB6aAADkdxAA5H4JANs6BwALcgAA8FoAABAPAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":f ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(hb_trip.loc[hb_trip['auto_ownership_4+']!="-1"],"auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: other–survey only"]},
                 "auto ownership",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3c74a452-2102-4509-89b3-e2f659f8dea3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3c74a452-2102-4509-89b3-e2f659f8dea3")) {                    Plotly.newPlot(                        "3c74a452-2102-4509-89b3-e2f659f8dea3",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"H2AFAFR6AAAawQAA0lwAAFNgAQDNAAAA418AAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"hcraDDR54z\u002fI84QiE56pP0+nfhJY47E\u002fA9AVWHTToD+SrUxnKaLJPzEn7PuLbTI\u002fibaQ3QaHoz8="},"xaxis":"x5","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"WwNtACoAQwAlAFsBAwAlAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"Rj3zSD3b4D8IlGyHtmWkP0pwdiBrD4Y\u002f73mVQ0pYtD+Mu+R0LSl1Pzi85tS+YNA\u002fFrVkJXkVLT\u002fglI\u002fl6fS0Pw=="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"YoUIAOTkAAARkhUAHfMKAHC7BACzsAAAupQAAGUTAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"cd+qr7k4yD82cMtl9TOVP35n\u002fgeYXNw\u002fJvu93qqyyz+OI0EpQBW4P\u002fpDiS6Z8Zc\u002fVcowJaijhj+0YAgHvndgPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"qQXUAFIJ1gMmAusAHwAPAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"8ljYYkdhyD8ZKMcwv3iOP8yqG2B239g\u002fZxYAADMPzj\u002fhfeK6X0O3P0i8ITHuZbI\u002fWJHCCK8TfD9Id8vNPeRZPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"SSALABImAQDsKSYAo3UVAFYZDQCwkQAAlzEBAMIUAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","o ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(hb_trip.loc[hb_trip['auto_available_driver'] != "no dirver"], "auto_available_driver",
                 {"auto_available_driver": ["no car", "cars fewer than drivers", "enough cars"],
                  "mode_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit",
                                   "8: school bus","9: other–survey only"]},
                 "auto availability (driver, showing only households with at least one driver)", 3, 500, 1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="701ef8d3-0a1c-4427-bd60-e15c0f1ef8e5" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("701ef8d3-0a1c-4427-bd60-e15c0f1ef8e5")) {                    Plotly.newPlot(                        "701ef8d3-0a1c-4427-bd60-e15c0f1ef8e5",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"H2AFAFR6AAAawQAA0lwAAFNgAQDNAAAA418AAA==","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"hcraDDR54z\u002fI84QiE56pP0+nfhJY47E\u002fA9AVWHTToD+SrUxnKaLJPzEn7PuLbTI\u002fibaQ3QaHoz8="},"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"WwNtACwASQAlAFsBAwAlAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"FZdpF9t64D+l\u002fCIxFfGjPwfpsyYpnIc\u002fsnugF2NauT9IxgV4LrB0P7JzfQwZA9A\u002fn1WphixvLD9UUPG\u002fFX20Pw=="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"108JAIY0AQDnahIAYJkTAMnqCwAnCgEAUg8BABAUAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"1e0xZOqTwz+UmgvTEbOVP2hnVmLmRtM\u002f\u002fMw092010z\u002f6NddWygbHPzbv8Mz6sZw\u002fWSLsDDzajj8uBRCJni5ZPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"iwOiAGkEnQOKAq0AKwAJAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Nwj6kL7jwD+KsbXrZxOZP89bQPiqYNM\u002fZwSyK5p41D+wyEA8HsLDP4B+3nyOd6k\u002fnGfRC4\u002f1jz+gMYG6rvdTPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: transit","8: school bus","9: tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"z80SAH7AAQCs20oAIJUeAPakEgDFpgAAtZIBACclAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003emode_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{ ...

# %% [raw]
# :::
