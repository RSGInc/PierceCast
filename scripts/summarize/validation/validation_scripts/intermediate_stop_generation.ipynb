# %% [raw]
# ---
# title: "Intermediate Stop Generation"
# date: today
# ---

# %%
import polars as pl
import os
import pandas as pd
import numpy as np
# import validation_data_input
import plotly.express as px
import toml
from pathlib import Path
import util
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
# %store -r validation_data

# config = validation_data.config.copy()
# tour = validation_data.tour.copy()

config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['tour'])

tour = data.tour.to_pandas()

# %%
# df_person = person.copy()
df_tour = tour.copy()

# ptype_cat = {1: "1: full time worker",
#              2: "2: part time worker",
#              3: "3: non-worker age 65+",
#              4: "4: other non-working adult",
#              5: "5: university student",
#              6: "6: grade school student/child age 16+",
#              7: "7: child age 5-15",
#              8: "8: child age 0-4"}
pdpurp_cat = {1: "Work",
              2: "School",
              3: "Escort",
              4: "Personal Business",
              5: "Shop",
              6: "Meal",
              7: "Social",
              8: "Social",
              9: "Personal Business"}
# df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)
# df_person['pptyp_label'] = df_person['pptyp_label'].astype(pd.CategoricalDtype(["1: full time worker","2: part time worker","3: non-worker age 65+","4: other non-working adult","5: university student","6: grade school student/child age 16+","7: child age 5-15","8: child age 0-4"]))

df_tour['pdpurp_label'] = df_tour['pdpurp'].map(pdpurp_cat)
df_tour['pdpurp_label'] = df_tour['pdpurp_label'].astype(pd.CategoricalDtype(["Work","School","Shop","Meal","Escort","Personal Business"]))

df_tour['all_stops'] = df_tour['tripsh1'] + df_tour['tripsh2']
df_tour = df_tour.sort_values(['source'])
# df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %% [raw]
# :::{.panel-tabset}
# ### outbound: first half tour

# %%
df_plot = df_tour.groupby(['tripsh1','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]

fig = px.bar(df_plot.sort_values(['source']), x="tripsh1", y="percentage", color="source",
             barmode="group",title="outbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0783f4e1-360b-4da0-8d91-e17eb75c0543" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0783f4e1-360b-4da0-8d91-e17eb75c0543")) {                    Plotly.newPlot(                        "0783f4e1-360b-4da0-8d91-e17eb75c0543",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"c31usWNCUUGHwypBCbUtQQya3b\u002f\u002fhQxBWMMAemr16kAImWBgBIvSQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x","y":{"dtype":"f8","bdata":"U2AuYLHl6D97E655Rm3FPx9\u002fyT20kqQ\u002fUvaApsZxgz+xZCUqwL9qPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"GRyvQPJ5T0F2dyDHReYiQRIOKhXCZglBWlKXE7cw7kBrx4NbTdfKQJUaN40pKtBA","shape":"6, 1"},"hovertemplate":"source=survey\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUG"},"xaxis":"x","y":{"dtype":"f8","bdata":"fV3J4Zwj6j9+SSGjwWO\u002fP9fijLYgGKU\u002f6BkeDjUSiT9hgIkiLkpmP15ZpE\u002f22Go\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogr ...

# %% [raw]
# ### inbound: second half tour

# %%
df_plot = df_tour.groupby(['tripsh2','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]
# df_plot
fig = px.bar(df_plot.sort_values(['source']), x="tripsh2", y="percentage", color="source",
             barmode="group",title="inbound: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ec187ac6-2ce3-4858-930b-421c91fb28d1" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ec187ac6-2ce3-4858-930b-421c91fb28d1")) {                    Plotly.newPlot(                        "ec187ac6-2ce3-4858-930b-421c91fb28d1",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"nUHl5V21TEGb4JPjf1A2QTcVMRRK6hpBNyT+fN9w+EBTBjUchw3fQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x","y":{"dtype":"f8","bdata":"thc3dN605D\u002fPFYlpPxjQP4\u002fepDDAabM\u002fs\u002fuiJOOgkT\u002fT7wwRv2V2Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"F1DOVSuCwUB10q6d7R1LQS2rPVITGi1B6mucnHo3E0Ei\u002fKsURrP+QBaE92kIM+lAW4V8UMzi1EAx7iuLSTDSQA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AAECAwQFBgc="},"xaxis":"x","y":{"dtype":"f8","bdata":"sJg3ZVAUXT9Z\u002fkWk1ITmP3GTo4\u002fQKsg\u002fe6MtQKHqrz\u002f2mfq8oH6ZPy7lDlks7YQ\u002fjN10Ji1YcT\u002fBN+x+gDVuPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"# ...

# %% [raw]
# ### all stops

# %%
df_plot = df_tour.groupby(['all_stops','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot = df_plot.loc[df_plot['percentage'] > 0.001]
# df_plot
fig = px.bar(df_plot.sort_values(['source']), x="all_stops", y="percentage", color="source",
             barmode="group",title="all stops: number of stops (excluding shares < 1%)",
             hover_data=['toexpfac'])
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".0%"))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a9a22543-cc42-420f-868e-c506d1666728" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a9a22543-cc42-420f-868e-c506d1666728")) {                    Plotly.newPlot(                        "a9a22543-cc42-420f-868e-c506d1666728",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"PMvqKnHzR0G5Un0oTyy6QPB6dNvrG81AmA6nlD7V4kCzom\u002fWR84QQb+1nQcw6vlA4iRWUI6LJUH4nUqV0x43QQ==","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AgkIBwUGBAM="},"xaxis":"x","y":{"dtype":"f8","bdata":"weiA+GpG4T90B9JWueBSP3SsmJ3W\u002fmQ\u002fGvMDj9Mqez9bCb2YMz6oP+qqXVQIsZI\u002f21Whk2UUvz8XKxOcEK3QPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"d7ZGXaYpDUG+y4o0eujTQExmxrobkvVAEpI4B4I0MEHdkWpVes7jQDJ5\u002fHciTNJA\u002faVukdspR0E4DX7tGiQgQfr+\u002fr16e8lA","shape":"9, 1"},"hovertemplate":"source=survey\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"BQkGAwcIAgQK"},"xaxis":"x","y":{"dtype":"f8","bdata":"604ZjL83qD\u002fDcekGTYhwP\u002frCvafC6ZE\u002fqrUrGCXqyj8H\u002f4q\u002ftXKAPwdKMLzAY24\u002fDvVWzl484z9dUPLr5s66P+ORYeVVKWU\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.44444444444444 ...

# %% [raw]
# :::

# %% [markdown]
# ## number of stops by purpose

# %% [raw]
# :::{.panel-tabset}
# ### outbound

# %%
df_plot = df_tour.groupby(['tripsh1','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['tripsh1'] <= 10)]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="tripsh1", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2, 
             hover_data=['toexpfac'],
             title="outbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\3254560635.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\3254560635.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="194d6b10-9cf9-4f77-9e3a-1585b4b746d2" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("194d6b10-9cf9-4f77-9e3a-1585b4b746d2")) {                    Plotly.newPlot(                        "194d6b10-9cf9-4f77-9e3a-1585b4b746d2",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"9JhmpfOuMEH9YhALpOIVQYMeN2BDR\u002flAI2Y9A9K53ECUmLAbRMvHQLtNq7\u002f6QqpACPa6qSwsnkA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBw=="},"xaxis":"x5","y":{"dtype":"f8","bdata":"61uwaWvN5T\u002f4QlzltpnMP3yZUudthLA\u002fy7VQSxvFkj\u002fL9jETRBh\u002fPw4iEqXnKGE\u002fwDgWIBq3Uz8="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"cV4D7J0UHEHzZfgeR7z6QNbKJktVRtpAlOIvnLUFt0C3c0glNPaZQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x6","y":{"dtype":"f8","bdata":"G8dPWOpa6D\u002flMw5cQjDHPzQQpEv2yaY\u002f9FGNFM33gz\u002fztXmXdoRmPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"sJK+mchOIUH2bdQzfa7+QLVOC51TOt1AndqnwqNduECJRKW\u002fzpmZQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x3","y":{"dtype":"f8","bdata":"eZyTxHTT6D8jaX6+LwHGP6ZqcitG9qQ\u002fbN\u002fX0Zd5gT+bIBy3WFxiPw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"sG9MLo7KEkFlV2b4ExzrQB807kbe+clALbYlQ9Z8pkDL7pVWANCIQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x4","y":{"dtype":"f8","bdata":"A3mnjiXj6T+kKKeUaqzCP5c1ax2E5KE\u002f1ZLJ1sT6fj\u002fLdwloVxdhPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"tsaI+vpKHkFWQpuaGFb5QEqbFih9R9ZAGofBRQvaskBXipE06G2UQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh1=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x","y":{"dtype":"f8","bdata":"42wrWes76T\u002fg3sxy7xrFP5waqH0Fj6I\u002fbN+5Dzdofz8W\u002fo7JhgRhPw=="},"yaxis":"y","type":"bar"}, ...

# %% [markdown]
# - outliers

# %%
df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['tripsh1'] > 10)]
# Out:
# Empty DataFrame
# Columns: [tripsh1, pdpurp_label, source, toexpfac, percentage]
# Index: []

# %% [raw]
# ### inbound

# %%
df_plot = df_tour.groupby(['tripsh2','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[df_plot['percentage'] > 0.001]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="tripsh2", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="inbound: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\1171881886.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\1171881886.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="acc1e0da-4f8b-44f6-a21f-a44d0b61de31" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("acc1e0da-4f8b-44f6-a21f-a44d0b61de31")) {                    Plotly.newPlot(                        "acc1e0da-4f8b-44f6-a21f-a44d0b61de31",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"LU8DGkV1JUHx5hvQ4tcgQcbn2kdBEg1BolYew+gH8UBcS1xBxLLZQG6HpLEdY69AoH84EuOdp0DKv7FS1EShQMsfJJkpK5pA","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJ"},"xaxis":"x5","y":{"dtype":"f8","bdata":"YLpX9sgK3D\u002fNzmHu6QLWP\u002fwwnink\u002fsI\u002fwVUNEaxBpj+EDS9\u002frMqQP1AH\u002fL1GgmQ\u002fkXb4jPbcXj9wvC3bSJFWPwfEtqpXGVE\u002f"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"t94S7HRLFkG3OEPxi0QEQSy4ZVzM\u002f+tAgfUHqIV8x0B+Fsn3o+ulQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x6","y":{"dtype":"f8","bdata":"QIqAG0JW4z9M76LpMJTRPxfiAdnbSLg\u002fTVLB4dlelD9+fxJeJwNzPw=="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"m0+8SRg1H0Fw6IuDF2UFQfMHzb3KwOJA+SXUZCQatEAhrvNIFlaIQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x3","y":{"dtype":"f8","bdata":"90VHkblh5j9mTYc8RLDOP2anSO0w5qo\u002fM++viY7VfD9+X+okLXRRPw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"FYETHr2LEUFym907F33yQJ7zTFPSDc1AFEQzbDFooEA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBA=="},"xaxis":"x4","y":{"dtype":"f8","bdata":"sV2Ewu8r6D8ruEjtbXjJP1YpJMNEA6Q\u002fJ0ORrUuadj8="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"IKdZoNZCGkGRuFXlyCUDQciDL4HYrOFAit7iC5IDtECuhUa5ybaIQA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003etripsh2=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAU="},"xaxis":"x","y":{"dtype":"f8","bdata":"1y05bSTg5T+TqfxGZubPP99BcsZqcq0\u002fHHsKqPKrgD9aiFYzO5ZUPw=="},"yaxis":"y","type":"bar"},{"alignme ...

# %% [raw]
# ### all stops

# %%
df_plot = df_tour.groupby(['all_stops','pdpurp_label','source'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['pdpurp_label','source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))
df_plot2 = df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['all_stops'] <= 10)]

fig = px.bar(df_plot2.sort_values(['source','pdpurp_label']),
             x="all_stops", y="percentage", color="source",barmode="group",
             facet_col='pdpurp_label', facet_col_wrap=2,
             hover_data=['toexpfac'],
             title="all stops: number of stops by purpose (excluding shares < 1%)")
fig.update_layout(height=800, width=800)
fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
fig.for_each_xaxis(lambda a: a.update(dict(dtick = 1, categoryorder='category ascending')))
fig.show()
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\1285805814.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_468960\1285805814.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3524a863-153f-4e95-a58f-ba53bd5b3017" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3524a863-153f-4e95-a58f-ba53bd5b3017")) {                    Plotly.newPlot(                        "3524a863-153f-4e95-a58f-ba53bd5b3017",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"E62LlG9MIEEZFYyQfKQdQTJQ9tknqhJBmdYYXNVdAkEadg0ySv3wQEbRDZst+9tA6L2MF9EXyEDu317JfHq3QIoguu02Na1A","shape":"9, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Work\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEBQYHCAkK"},"xaxis":"x5","y":{"dtype":"f8","bdata":"fDhJAa1M1T+TRW\u002f9cF7TP95rZRJAZMg\u002fQiz9h4IAuD8dQcxayzOmP0b1F7KJSJI\u002fJ+4bDk58fz\u002fQBxSps65uPwU7UQK8FWM\u002f"},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"ORMBFsm8EkH8VaoZkuECQUMaNfmGRPVA+4oZTAv94UA2XGmUygzJQFm6qRQ8Kq9AvOyUPe35kUA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=School\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEBQYHCA=="},"xaxis":"x6","y":{"dtype":"f8","bdata":"Dm3aeGdA4D8TELIlT2DQP7fu3g02csI\u002fgQsgnzM0rz84dcxtBLqVP+CMdqbGB3s\u002ftLcEQ8suXz8="},"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"MI7wp4E7GUGqxsgJFFAIQbPcWVFeUPRAjhJXlOL62EDithyzNDe8QOsDL65cEJxA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Shop\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEBQYH"},"xaxis":"x3","y":{"dtype":"f8","bdata":"7eYB47YY4j8B6Yzs3W\u002fRP9gu+pRWI70\u002fXcbSTV7qoT\u002f6erk3bzyEPz+nKm+TIGQ\u002f"},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"Bw6BP5ODDUFyTHvU9ff1QCaOSQLDf+BA8xjVAJzsxEC\u002fJcgMqNSoQGCszGqwwopA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Meal\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEBQYH"},"xaxis":"x4","y":{"dtype":"f8","bdata":"XMuA+mBU5D9vyuzptkPOP2k3OLTDurY\u002fwwmTqmfTnD\u002f3juFFjBqBP4x2LhfYbmI\u002f"},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"CtAjRSqmFUGtKerOUxUFQQI3napnY\u002fFA+FLMOu1n1UAKEFxkKgm5QPMBdR5NrptA","shape":"6, 1"},"hovertemplate":"source=model\u003cbr\u003epdpurp_label=Escort\u003cbr\u003eall_stops=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003etoexpfac=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AgMEBQYH"}, ...

# %% [markdown]
# - outliers

# %%
df_plot.loc[(df_plot['percentage'] > 0.001) & (df_plot['all_stops'] > 10)]
# Out:
#      all_stops       pdpurp_label  source     toexpfac  percentage
# 132         11               Work   model  2440.784347    0.001521
# 143         11  Personal Business  survey  1001.476382    0.002894
# 144         12               Work   model  1643.544320    0.001024

# %% [raw]
# :::
