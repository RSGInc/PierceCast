# %% [raw]
# ---
# title: "Escort Tour Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
# import validation_data_input
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
# %store -r validation_data

# config = validation_data.config.copy()
# hh = validation_data.hh.copy()
# person = validation_data.person.copy()
# trip = validation_data.trip.copy()
# df_parcel = validation_data.land_use.copy()

config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'tour', 'land_use'])

hh = data.hh.to_pandas()
person = data.person.to_pandas()
tour = data.tour.to_pandas()
df_parcel = data.land_use.to_pandas()

# %%
df_tour = tour.copy()
df_hh = hh.copy()
df_person = person.copy()

# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9: tnc"}
df_tour['tmodetp_label'] = df_tour['tmodetp'].map(mode_cat)

df_hh = df_hh.merge(df_parcel,how="left",left_on='hhno',right_on='parcelid')
df_person = df_person.merge(df_hh, how='left', on=['hhno','source']) # get auto ownership from hh data

df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
es_tour = df_tour.loc[(df_tour['parent']==0) & (df_tour['pdpurp']==3)].copy()

# %%
df_plot = es_tour.groupby(['source','tmodetp_label'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = es_tour.groupby(['source','tmodetp_label'])['toexpfac'].count().reset_index(). \
    rename(columns={'toexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','tmodetp_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="tmodetp_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="escort tour mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="cd9288bf-f28f-4db7-8a98-9671fd1a23c0" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cd9288bf-f28f-4db7-8a98-9671fd1a23c0")) {                    Plotly.newPlot(                        "cd9288bf-f28f-4db7-8a98-9671fd1a23c0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"5PAAACYKAAD+bQAAdDsFAA6xBQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"xaxis":"x","y":{"dtype":"f8","bdata":"VseZmkWRtT\u002fx7C\u002fpPWBuP8v\u002frrT6DqE\u002fJjvtlt7R2z8yEwQwMGvcPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"ZgAPAC0AVgH8AAsAAwABAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","8: school bus","9: tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"6qm4b+d5tz+D+G0HhIppP+3AVqUhkqE\u002fMabZ51zB2z+uzBlXKYjbP3eR6KYb+3o\u002fqYUd\u002fHg3Oj\u002fiongCxS3mPg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[ ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### person type

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['toexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].count().reset_index(). \
        rename(columns={'toexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'tmodetp_label'])

    fig = px.bar(df_plot.sort_values(['source','tmodetp_label']),
                 x="percentage", y="tmodetp_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 category_orders=order_list,hover_data=['sample count'],
                 title="escort tour mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
plot_mode_choice(es_tour,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "person type",
                 2,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="eb041469-d9cf-4688-ae9b-d43a9d11ab53" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eb041469-d9cf-4688-ae9b-d43a9d11ab53")) {                    Plotly.newPlot(                        "eb041469-d9cf-4688-ae9b-d43a9d11ab53",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"yEIAAG8BAABoGQAA3j4BAANCAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"+cgOQVExuj\u002f1Ssu\u002fwGhjP\u002flGQwwOAKE\u002fAXyVDWyX3D9N0h5fbJXaPw=="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"IwgKckIC","shape":"6, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"bO87Ccrvwj9GMwV3Rf6CPwtdycBGaY8\u002fxiGLzEd94D8OKZrFuufTP9spJ\u002fM6lFI\u002f"},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"HhieAKQJtXgleQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bkUNO2lCuD\u002fQmeqSU\u002fZlP+OMDLOwu6E\u002f3lbPlryY3D\u002f28OVcRvPaPw=="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BwIfHAE=","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"OBoe8TtYlj8qKpyZPgtqP2AuamA9huI\u002fSvESNVlO2T\u002fA\u002fC+nmyNHPw=="},"xaxis":"x8","y":["1: walk","3: sov","4: hov 2","5: hov 3+","6: walk to transit"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"TyAAAOUCAADHHgAAnw0BAJiRAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=non-worker age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Wf1FvLCksz+GlCy3M\u002fd9PyXwf0BPxK4\u002fRL+GXUPu4T\u002fMUfRe5unSPw=="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y5","t ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(es_tour,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "household size",2,600)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6c5323d8-cf4d-4c7c-b623-7f5d1328f0f1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6c5323d8-cf4d-4c7c-b623-7f5d1328f0f1")) {                    Plotly.newPlot(                        "6c5323d8-cf4d-4c7c-b623-7f5d1328f0f1",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"ESXVAsQIHE20IQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ZauLAKb20D+RQa5EILKTP4ddsqjPAKk\u002fofAtodjc3T9haMrJiqLJPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BAYTAQM=","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"gQCMo2lbfz9rwanUuui3P9k7I+Hm1d8\u002fo3XZ2Ywa1T+cuCqlv1+yPw=="},"xaxis":"x3","y":["1: walk","3: sov","4: hov 2","5: hov 3+","6: walk to transit"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ajwAADoCAACoHwAAe0ABAJqGAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"IfocRjJAwD+W7hCGlih0P2Bw0Ofzvqo\u002fNWM8dbp84j+A1cw24nvOPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BxBSHQMB","shape":"6, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bQC\u002fui40cT8tbjPsOw62PxkGtL4ZW+A\u002flA8Jn89g2T+zseW3xAlaP\u002fPom3yjTTo\u002f"},"xaxis":"x4","y":["1: walk","3: sov","4: hov 2","5: hov 3+","6: walk to transit","8: school bus"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"czkAAJcBAADpFQAAICIBAOfCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"CSJjYepruj8rsRflLelqPwsM4CcXr6I\u002f6uR\u002fYd9a4D\u002fGPOFjkSPWPw=="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"FggETSMD","shape":"6, 1"},"hovertemplate":"sou ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(es_tour.loc[es_tour['auto_ownership_4+']!="-1"],
                 "auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "auto ownership",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="14cbdaad-a063-4b85-be65-cf224340fd30" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("14cbdaad-a063-4b85-be65-cf224340fd30")) {                    Plotly.newPlot(                        "14cbdaad-a063-4b85-be65-cf224340fd30",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"j18kCp8CFgQ=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"SA0h95R46z+wS0vrXyy2Pw4AVUxUv5c\u002fHRQukUY+oD8="},"xaxis":"x5","y":["1: walk","2: bike","4: hov 2","5: hov 3+"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BAEBBA==","shape":"4, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ik64pXGhxz+Afcf5XrKzP5SYSCsH3sM\u002fidaG7NWp4j8="},"xaxis":"x5","y":["1: walk","3: sov","4: hov 2","6: walk to transit"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"YSMAAAUTAABtLAEALOwAAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"kOQLSWPUsD\u002fyJqFdsyOfP6FEG1lpj+A\u002fLWusRdm52D8="},"xaxis":"x6","y":["1: walk","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"KAcNYDcEAg==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ip91k0hlvT+NrvlGoM2WPz6SVsNhu6A\u002fIjvr5\u002fyE4D8rR0SE1GvRP8HqefRs3KQ\u002flSYwnqsLUT8="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","8: school bus"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"qz8AAIUuAAD9NQIAKJ0CAA==","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"Y6ilp\u002fYKqT\u002f1w+k8CuagP\u002fIH4bp5qNs\u002fhAqNKGYZ3z8="},"xaxis":"x3","y":["1: walk","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"IAAEAAgAlQCPAAEAAQA=","shape":"7, 1"},"hovertemplate":"source=survey\u003c ...

# %% [raw]
# ### Household Type

# %%
plot_mode_choice(es_tour,
                 "hhcu5",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "HH with Children Under 5",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="8eb52c00-4017-408d-89a2-91acafd9f01d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8eb52c00-4017-408d-89a2-91acafd9f01d")) {                    Plotly.newPlot(                        "8eb52c00-4017-408d-89a2-91acafd9f01d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"GLkAAJkHAAB0VwAA5dADAGAOAwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhcu5=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"2SQ7jdYquT9u2+lqlTNxP91S9zHOcaQ\u002fmRvAmYyO3j9miQantVPYPw=="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vC0AAAECAAA9EgAAKBYBAAzPAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhcu5=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"b60mp669rz90JQfFy3BoP3PpnrpD6JY\u002fszZp+I7B1z9f+76vqlPhPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"WQkAAHYAAADyAwAASU8AAIa+AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhcu5=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"D9kysAaxpD+qLNzikYRePwZEIuHxMI0\u002fwxD1zU0z0z\u002fnUoydQpfkPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"sQAUAFoA6QTUEg==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhcu5=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"VETvhk7\u002foj\u002fln\u002f0o3QNtPxwxYanLTYU\u002fSUCQZkVsyT9FeR6yvgLoPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"BQABAAEAMQALAQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhcu5=4.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"veV+vZAhlz\u002f5ms0y559CP\u002fmazTLnn0I\u002ftNbz84Q1vj8uJ\u002fzn8nbrPw=="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"AQABAAQAPQE=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u00 ...

# %% [raw]
# ### Kids 5-15

# %%
plot_mode_choice(es_tour,
                 "hh515",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "HH with Children 5-15",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="adfd95ac-5a17-430b-b352-607bda1150ac" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("adfd95ac-5a17-430b-b352-607bda1150ac")) {                    Plotly.newPlot(                        "adfd95ac-5a17-430b-b352-607bda1150ac",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"U5wAACIGAAAbQwAAPRoDACCLAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh515=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"io\u002fashIYvz\u002fzADQLTFl0PydMxZ24fqY\u002fzrlKegbK4T\u002f6bs4asoTRPw=="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vzkAAKgCAABkGwAAXGsBAOO7AQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh515=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ovZq9lfdsD8oX2Wzj8tpPzg4BLKI750\u002f+7GK7j0x2j8aglNp3ITfPw=="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"gBUAAAMBAACDDAAAAZYAAAtmAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh515=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"KOfHVNFmpT9OrCmLA4xiP80sPFwTu5U\u002foxYnNzpg0j8p67IwEbnkPw=="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"2AMAAEEAAABiAgAAqxoAAHWSAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh515=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"iNh1iGIOmT8oH6SOPuBaP1fqeyMC34o\u002fSvIlpfU8wz\u002fxkp1aY+\u002fpPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"PwEXAIMAZQRoRg==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh515=4.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"DH8YUtlDkT8FryHek9lPP4cIAdD+IXs\u002fezcXKc23sD+byrQtrSDtPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"FAAJAGYANgw=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr ...

# %% [raw]
# ### High School Students

# %%
plot_mode_choice(es_tour,
                 "hhhsc",
                 {
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "HH with Driving Age Students",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="eaa3529b-7e43-4d6a-b29d-392e262f905d" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eaa3529b-7e43-4d6a-b29d-392e262f905d")) {                    Plotly.newPlot(                        "eaa3529b-7e43-4d6a-b29d-392e262f905d",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"auYAAE0JAACcZAAA+roEAGnVBAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhhsc=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ccBPRew8tz+W0Zc1sNVvP4QVyvybZ6E\u002fttos5eAx3D\u002fZwnopRZLbPw=="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"zAgAAJgAAAB1CAAA9XQAAE+yAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhhsc=1.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"ZA7WyBlanT9GmPkl4X9gP3n23tnPDJ0\u002f8WFKHtOW2T9ILZ9C31DhPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"mQFBAOAAKwuxKA==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhhsc=2.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"IY\u002f2iUWhnT8vdhW2hthsP6gdZyTHO5Y\u002fKo4Aew3Y0T8OtlZWOFjlPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"FQANAFoAoQA=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003ehhhsc=3.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"CK6CDMKZoD+JDkLzxp6fP1duyhkEF9M\u002fgY24mutt5D8="},"xaxis":"x4","y":["1: walk","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BA==","shape":"1, 1"},"hovertemplate":"source=model\u003cbr\u003ehhhsc=6.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAA8D8="},"xaxis":"x","y":["5: hov 3+"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"TwAKABsAAgHUAAkAAwA=","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhhsc=0.0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(es_tour.loc[es_tour['auto_available_driver'] != "no dirver"], "auto_available_driver",
                 {"auto_available_driver": ["no car", "cars fewer than drivers", "enough cars"],
                  "tmodetp_label": ["1: walk", "2: bike", "3: sov", "4: hov 2", "5: hov 3+", "6: walk to transit",
                                    "7: park-and-ride", "8: school bus", "9: other–survey only"]},
                 "auto availability (driver, showing only households with at least one driver)", 3, 500, 900)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="da32e00a-5bc2-4f2c-8946-bb6f7f46d78c" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("da32e00a-5bc2-4f2c-8946-bb6f7f46d78c")) {                    Plotly.newPlot(                        "da32e00a-5bc2-4f2c-8946-bb6f7f46d78c",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"j18kCp8CFgQ=","shape":"4, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"SA0h95R46z+wS0vrXyy2Pw4AVUxUv5c\u002fHRQukUY+oD8="},"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"BAEBBA==","shape":"4, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"ik64pXGhxz+Afcf5XrKzP5SYSCsH3sM\u002fidaG7NWp4j8="},"xaxis":"x","y":["1: walk","3: sov","4: hov 2","6: walk to transit"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"pisAAAEAAAC3GwAAyegBAGO4AQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"evcxxusIqD9nc94+2uq0Pik0j8FHBZw\u002f5TtrcAxj4D9MxpPvb3jaPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"JwcNZDcCAQ==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"4W4AVADsuz8SH2w6nuOKP5P9gP9Ak5I\u002f2gAqskt95T+REd5jXCzFP8Oi4mXR8JY\u002fPTP7TPJwMz8="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","8: school bus"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"r2UAAAEAAABHUgAADFADAJX0AwA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"DSBYQLkYqj8NeoX49OSkPmGRkSWEuaM\u002fCFjHInwc2z+50tyTOSnfPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","cu ...

# %% [raw]
# :::
