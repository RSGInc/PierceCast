# %% [raw]
# ---
# title: "Work Tour Mode"
# date: today
# ---

# %%
import os
import pandas as pd
import numpy as np
import validation_data_input
import plotly.express as px
import toml
import polars as pl
from pathlib import Path
import util
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

data = util.ValidationData(config,input_config,['hh', 'person', 'tour', 'land_use'])

hh = data.hh.to_pandas()
person = data.person.to_pandas()
tour = data.tour.to_pandas()
df_parcel = data.land_use.to_pandas()

# %%
df_tour = tour.copy()
df_hh = hh.copy()
df_person = person.copy()

# Add column for (potential) drivers adults (all hh members 16 and above)
df_hh['drivers'] = df_hh['hhsize']-df_hh['hh515']-df_hh['hhcu5']#-df_hh['hhhsc']
# auto_ownership with 4+
df_hh['auto_ownership_4+'] = df_hh['hhvehs'].apply(lambda x: "4+" if x>=4.0 else str(x))
# hhsize with 4+
df_hh['hhsize_4+'] = df_hh['hhsize'].apply(lambda x: "4+" if x>=4.0 else str(x))
# auto availability
df_hh['auto_count_driver'] = df_hh['hhvehs']-df_hh['drivers']
df_hh['auto_count_worker'] = df_hh['hhvehs']-df_hh['hhwkrs']
df_hh['auto_available_driver'] = np.where(df_hh['drivers']<=0, "no driver",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_driver']<0, "cars fewer than drivers", "enough cars")))

df_hh['auto_available_worker'] = np.where(df_hh['hhwkrs']<=0, "no worker",
                                          np.where(df_hh['hhvehs']<=0, "no car",
                                                   np.where(df_hh['auto_count_worker']<0, "cars fewer than workers", "enough cars")))


# add person type labels
ptype_cat = {1: "full time worker",
             2: "part time worker",
             3: "non-worker age 65+",
             4: "other non-working adult",
             5: "university student",
             6: "grade school student/child age 16+",
             7: "child age 5-15",
             8: "child age 0-4"}
df_person['pptyp_label'] = df_person['pptyp'].map(ptype_cat)

mode_cat = {1: "1: walk",
            2: "2: bike",
            3: "3: sov",
            4: "4: hov 2",
            5: "5: hov 3+",
            6: "6: walk to transit",
            7: "7: park-and-ride",
            8: "8: school bus",
            9: "9:tnc"}
df_tour['tmodetp_label'] = df_tour['tmodetp'].map(mode_cat)

df_hh = df_hh.merge(df_parcel,how="left",left_on='hhno',right_on='parcelid')
df_person = df_person.merge(df_hh,  how='left', on=['hhno','source']) # get auto ownership from hh data

df_tour = df_tour.merge(df_person, how='left', on=['pno','hhno','source'])

# %%
wk_tour = df_tour.loc[(df_tour['parent']==0) & (df_tour['pdpurp']==1)].copy()

# %%
df_plot = wk_tour.groupby(['source','tmodetp_label'])['toexpfac'].sum().reset_index()
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['toexpfac']. \
    apply(lambda x: x / float(x.sum()))

df_plot_ct = wk_tour.groupby(['source','tmodetp_label'])['toexpfac'].count().reset_index(). \
    rename(columns={'toexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','tmodetp_label'])

fig = px.bar(df_plot.sort_values(by=['source']), x="tmodetp_label", y="percentage", color="source",
             barmode="group",hover_data=['sample count'],title="work tour mode")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  xaxis = dict(dtick = 1, categoryorder='category ascending'),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d30b3153-8e6f-44b6-a2c1-fd9d024686e2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d30b3153-8e6f-44b6-a2c1-fd9d024686e2")) {                    Plotly.newPlot(                        "d30b3153-8e6f-44b6-a2c1-fd9d024686e2",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"t9oAAAliAAC1wxAAlTMEAHSCAwBQkAAA6SEAAHE0AAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"TzT\u002fMcP2pT9SjP0R802RP9+p5SzCzOM\u002fq2IrY4d3wz8qwR1q8BvAPy1W9ggHNpw\u002fRFKz9UqKdT94C0V50e+FPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"8QCIAH0F\u002fgBsAG4BHAAXAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003etmodetp_label=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"xaxis":"x","y":{"dtype":"f8","bdata":"lBD+5mePpD\u002fMQRs9nCiKP1mKgwFUHuQ\u002fYhOFt1ecwj8lCS8CdWC+P+hZAF2qK6M\u002fn29PO4EOfT8nR5cqtgWEPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[ ...

# %% [markdown]
# ### mode choice by segment

# %% [raw]
# :::{.panel-tabset}
#
# ### person type

# %%
def plot_mode_choice(df: pd.DataFrame, grp_var: str, order_list: dict, title_name: str, n_nol: int, height=400, width=800):
    df_plot = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',grp_var], group_keys=False)['toexpfac']. \
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df.groupby(['source',grp_var,'tmodetp_label'])['toexpfac'].count().reset_index(). \
        rename(columns={'toexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',grp_var,'tmodetp_label'])

    fig = px.bar(df_plot.sort_values(['source','tmodetp_label']),
                 x="percentage", y="tmodetp_label", color="source",barmode="group",
                 facet_col=grp_var, facet_col_wrap=n_nol, orientation='h',
                 hover_data=['sample count'],
                 category_orders=order_list,
                 title="work tour mode choice by " + title_name)
    fig.update_layout(height=height, width=width)
    fig.for_each_annotation(lambda a: a.update(text = a.text.split("=")[-1]))
    fig.for_each_xaxis(lambda a: a.update(tickformat = ".1%"))
    fig.show()

# %%
plot_mode_choice(wk_tour,"pptyp_label",
                 {"pptyp_label":["full time worker","part time worker","non-worker age 65+","other non-working adult",
                                 "university student","grade school student/child age 16+","child age 5-15","child age 0-4"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "person type",2,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="8f7847e8-28c3-47a8-ad08-9049fca290d0" class="plotly-graph-div" style="height:1000px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8f7847e8-28c3-47a8-ad08-9049fca290d0")) {                    Plotly.newPlot(                        "8f7847e8-28c3-47a8-ad08-9049fca290d0",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"VqYAAAdKAACnag0AdHkDAKjjAgB5fgAAUR8AAE4sAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"XUC3tmRVpT\u002fUJ6qL7qSQP8FqoZyUn+M\u002fAoMHDWzHwz\u002fPk8cZOEjAPxZRKSyke54\u002fuvMJoEBfeD\u002fF9SrQPVqHPw=="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"fgBdAEQDlABKANYAEAANAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=full time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"mu\u002f\u002f8rWaoj+QHXcJFNKKP1xl\u002fJLKKOM\u002f48+ckl5Dwz8CUc+OJgvDP8VTeSkSLKM\u002f13BldN9adj9et5X0ZMqDPw=="},"xaxis":"x7","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ZykAAPoPAAAffwIAv6MAAFyJAABUDAAAJAIAAEEGAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"hdT+FCrzqD9ndrFcRxmRPwRSjh56v+M\u002feERyLSFhxD\u002fP2jCYVRPBP++dZGRks44\u002f9AnxuqAhYz9t1nTDEL5+Pw=="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"EwAJAJgAGgAKABwAAgABAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=part time worker\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"9XBiecdqnj\u002fa52m1m7GKP94ji8nKXug\u002fDYp1NE6Quz+j1C0TJd6wP8T3bEcO9I8\u002fJs+goteBej9mGOovn44NPw=="},"xaxis":"x8","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"AgI=","shape":"2, 1"},"hovertemplate":"source=survey\u003cbr\u003epptyp_label=non-worker age 65+\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup": ...

# %% [raw]
# ### household size

# %%
plot_mode_choice(wk_tour,"hhsize_4+",
                 {"hhsize_4+":["1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "household size",2,600)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c52c019b-d4a0-4c9c-8523-daafd8a9f92b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c52c019b-d4a0-4c9c-8523-daafd8a9f92b")) {                    Plotly.newPlot(                        "c52c019b-d4a0-4c9c-8523-daafd8a9f92b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"L0QAAMoJAADgXgIA4hgAAJgXAAA8FwAA0QQAAKALAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"QOqpd4Dqvj92Gyz9RmGPP7URXz4Dmuc\u002f0jn\u002fjiatnj9aNJaaQ4WdP+Br3PjiOqM\u002fimdobfotfT+vsjcgRHGXPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"RwAfAPgADAANAGYACgAGAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"nXf6tGMUvD800tj8UguYP4WGIU8YKuU\u002f8v+X9VlWkz\u002f5NB4tS42nP2mEK+ANlbo\u002fneZhyHSCoT\u002fSrzFOF7BkPw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"3lMAAJQbAAAzrgUAmi8BAKBoAAAVLgAACAoAAHMRAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"40EDwlXOrD\u002fF9bpL\u002fnGRP+LXIxXx5+U\u002fdDs\u002fTMONwj+h2antfLCpP6BHPDd\u002fB54\u002fmiu32\u002fOedT+00ZdAxmmJPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"PAA0AKgBXgASAHIABwAHAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"QmWkErfmnT80zWiaOUSNP3EoKYzY7OQ\u002fnmzvSjlmxj8w9SyQWqilPxMbIgTDVq4\u002fBg7csCkjaz+iHs3kr0eXPw=="},"xaxis":"x4","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"kRwAAC0RAAD0TAMAAM4AAOPVAAAVGgAA4QYAAAAIAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_4+=3\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"s ...

# %% [raw]
# ### auto ownership

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_ownership_4+']!="-1"],"auto_ownership_4+",
                 {"auto_ownership_4+":["0","1","2","3","4+"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "auto ownership",2,800)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="03154830-a1b9-4fc6-904a-21f362567ecd" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("03154830-a1b9-4fc6-904a-21f362567ecd")) {                    Plotly.newPlot(                        "03154830-a1b9-4fc6-904a-21f362567ecd",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"oidPEcEAjwDSHVkFvxA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"2Wwr4OHA2T9HmFC5NjjBPyxyOuHjjnA\u002fNQR2zSoPbj\u002fnnFD9vWHPPxvzwN1GDqc\u002ftwhYBwIkxT8="},"xaxis":"x5","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"PRwEAmAICQ==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=0\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"b\u002fvHPwgF1T\u002fWPcn\u002fk6+9Pwdma954uoE\u002fScbjUE1+VD\u002f2sYMnuKzTP07iFozXxsA\u002fF0zJ+XJyuz8="},"xaxis":"x5","y":["1: walk","2: bike","3: sov","4: hov 2","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"u1IAAMAmAAC8kgMAC9QAAJGeAABOJgAAnQMAALMIAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"2jZIWEIosz9BtoY6ZQOeP9AuJ2cPk+M\u002fK1pgz8bKwT8E6I5hNUm6P0qhvfO5NqA\u002fBU3eMjrzZD9zLbqgeuWAPw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"SAA3AGkBRwAeAG8ABwAEAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_4+=1\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"FKw\u002fU7ZqrT+Gz20h7LSbP8J7B4eksuI\u002froMZ4S9zvz8SL5ANrFu8PxYYQ7oAvrY\u002fSkAaoPBNZz9fsrN9lg94Pw=="},"xaxis":"x6","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"fT4AAGYWAAAjDgcAatEBAOtsAQCULAAAzgwAAJoOAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_4+=2\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","or ...

# %% [raw]
# ### auto availability

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_available_worker']!="no worker"],"auto_available_worker",
                 {"auto_available_worker":["no car", "cars fewer than workers","enough cars"],
                     "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                      "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "auto availability (worker)",3,400,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="8099ba03-8fb8-406b-86e7-a74e89e38cb1" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8099ba03-8fb8-406b-86e7-a74e89e38cb1")) {                    Plotly.newPlot(                        "8099ba03-8fb8-406b-86e7-a74e89e38cb1",                        [{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"PRwFAl4ICQ==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"pA+PQEY51T9wY2D4W\u002fm9P8CT+\u002fDi6Y4\u002fuqX+dTyxVD9rBvjVctbSP5+Emu+J8MA\u002fA85Wfqq2uz8="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"JwAqAIMAMgASAEcAAgACAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=cars fewer than workers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"MEAlJ0spuz9TOy1LM6ekP4GO7sTMC90\u002foao4k25MwT+0z842PoTFP36U02KLHLY\u002f2ujnXNQWYT+k\u002fQAuZGqAPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"NwAiAGkDfABDAFkACgAFAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_worker=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"YoM+o0GckT+NKm+3vcF4P136ePXAQOU\u002fhlAVP5Tqwj\u002fBfpFO3XnBP9ATbL\u002f0qZM\u002fBretDdvIZT8ihbjFTlJ6Pw=="},"xaxis":"x3","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y3","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.44444444 ...

# %%
plot_mode_choice(wk_tour.loc[wk_tour['auto_available_driver']!="no dirver"],"auto_available_driver",
                 {"auto_available_driver":["no car", "cars fewer than drivers","enough cars"],
                  "tmodetp_label":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit",
                                   "7: park-and-ride","8: school bus","9: other–survey only"]},
                 "auto availability (driver, showing only households with at least one driver)",3,500,1000)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0d485088-881a-4b7f-bb5a-dad744ba3d18" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0d485088-881a-4b7f-bb5a-dad744ba3d18")) {                    Plotly.newPlot(                        "0d485088-881a-4b7f-bb5a-dad744ba3d18",                        [{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"oidPEcEAjwDSHVkFvxA=","shape":"7, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"2Wwr4OHA2T9HmFC5NjjBPyxyOuHjjnA\u002fNQR2zSoPbj\u002fnnFD9vWHPPxvzwN1GDqc\u002ftwhYBwIkxT8="},"xaxis":"x","y":["1: walk","2: bike","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"PRwFAmAICQ==","shape":"7, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=no car\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"A98oo2Hj1D\u002fkrjqrDYC9PyHGMDjHbI4\u002fwRqOZX5dVD\u002fpKrLCOI3TP86+T9f7q8A\u002folodLoJGuz8="},"xaxis":"x","y":["1: walk","2: bike","3: sov","4: hov 2","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"DTMAAJhFAAAkiwMAhaABANR1AQAtNgAASQQAAPwJAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bfbvx5Uioj\u002fGgyIax76kP+0tIEOSdd4\u002fdWiJ4\u002fZryz+fZ+7rgTfIPw6GcumaNaI\u002fDMXVD0WYYj90nedkdCh8Pw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"LgAvAN0ASgAXAFcABAADAA==","shape":"8, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_available_driver=cars fewer than drivers\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"f8","bdata":"bcWmIKiQrT+o+P7gJwCbP\u002f+hlD4xxN4\u002fDwmLeQsXzz94wBKWvOvAP1F848zC8Kg\u002f9eBGTzbpbj9N7ixPHBp\u002fPw=="},"xaxis":"x2","y":["1: walk","2: bike","3: sov","4: hov 2","5: hov 3+","6: walk to transit","7: park-and-ride","9:tnc"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"CIAAACILAACROA0AT5ICABEMAgBRPAAARxgAALYZAAA=","shape":"8, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_available_driver=enough cars\u003cbr\u003epercentage=%{x}\u003cbr\u003etmodetp_label=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marke ...

# %% [raw]
# :::
