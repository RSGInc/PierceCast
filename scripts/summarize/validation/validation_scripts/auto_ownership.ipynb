# %% [raw]
# ---
# title: "Auto Ownership"
# date: today
# ---

# %%
import polars as pl
import pandas as pd
import numpy as np
from sqlalchemy import create_engine,text
import plotly.express as px
import toml
from pathlib import Path
import util
import psrc_theme

# to show plotly figures in quarto HTML file
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"
pio.templates.default = "simple_white+psrc_color" # set plotly template

# %%
config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'validation_configuration.toml'))
input_config = toml.load(Path(Path.cwd(), '..\..\..\..\configuration', 'input_configuration.toml'))

# try:
#   %store -r data
#   print("read data from memory")
# except:
#   print("no data in memory")
data = util.ValidationData(config,input_config,['hh', 'land_use'])

land_use = data.land_use.to_pandas()
hh = data.hh.join(data.land_use, left_on="hhparcel", right_on="parcelid", how="left").to_pandas()

# %% [markdown]
# - income, hh density, employment density grouped into very low, low, medium, medium-high and high

# %%
# Group income, hh density, and employment density into 4 groups
var_group = hh.loc[hh['source'] == 'model',['hhincome','emptot_1','hh_1']].quantile([.125, .25, .50, .75])
var_group['labels']=['very low','low','medium','high']
var_group[['labels','emptot_1','hh_1']]
# Out:
#          labels    emptot_1        hh_1
# 0.125  very low    0.000000   68.073718
# 0.250       low    5.194211  135.705013
# 0.500    medium   78.236807  290.291721
# 0.750      high  357.588000  557.193932

# %%
income_4group = hh.loc[hh['source'] == 'model',['hhincome']].quantile([.25, .50, .75])
income_4group['labels']=['low','medium','high']
income_4group[['labels','hhincome']]
# Out:
#       labels  hhincome
# 0.25     low   52742.0
# 0.50  medium   97310.0
# 0.75    high  160521.0

# %%
# data manipulation
# hhwkrs is not always accurate; recalculate from part and full time workers
hh['hhwkrs'] = hh['hhftw']+hh['hhptw']
hh['hhwkrs']
# Add column for (potential) drivers adults (all hh members 16 and above)
hh['drivers'] = hh['hhsize']-hh['hh515']-hh['hhcu5']#-hh['hhhsc']

# add income group
hh['hhincome_group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + var_group['hhincome'].tolist(), labels=var_group['labels'])
hh['hhincome_4group'] = pd.cut(hh['hhincome'],bins=[-9999999.0] + income_4group['hhincome'].tolist(), labels=income_4group['labels'])
# add hh density groups
hh['hh_density_group'] = pd.cut(hh['hh_1'],bins=[-9999999.0] + var_group['hh_1'].tolist(), labels=var_group['labels'])
# add employment density groups
hh['emp_density_group'] = pd.cut(hh['emptot_1'],bins=[-9999999.0] + var_group['emptot_1'].tolist(), labels=var_group['labels'])

# add auto_ownership with 4+
hh['auto_ownership_simple'] = np.where(hh['hhvehs']>=4, "4+", hh['hhvehs'])
# add auto_ownership with 2+
hh['auto_ownership_2'] = np.where(hh['hhvehs']<2, hh['hhvehs'], "2+")
# add hhsize with 4+
hh['hhsize_simple'] = np.where(hh['hhsize']>=4, "4+", hh['hhsize'])
# add num_workers with 4+
hh['num_workers_simple'] = np.where(hh['hhwkrs']>=4, "4+", hh['hhwkrs'])
# add num_drivers with 4+
hh['num_drivers_simple'] = np.where(hh['drivers']>=4, "4+",hh['drivers'])

# %%
# Load ACS data
conn = create_engine('sqlite:///'+config['model_dir']+'/inputs/db/'+input_config['db_name'])
df_acs = pd.read_sql(text("SELECT * FROM observed_acs_vehicles_drivers"), con=conn.connect())
df_acs = df_acs.groupby('vehicles').sum()[['households']].reset_index()
df_acs.rename(columns={'households': 'hhexpfac'}, inplace=True)
df_acs['source'] = 'ACS'
df_acs.replace(4, '4+', inplace=True)
df_acs.rename(columns={'vehicles':'auto_ownership_simple'}, inplace=True)

# %%
# df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
# df_plot = pd.concat([df_plot,df_acs])
# df_plot = df_plot.reset_index(drop=True)
# df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
#         apply(lambda x: x / float(x.sum()))

# %%
df_plot = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].sum().reset_index()
df_plot = pd.concat([df_plot,df_acs])
df_plot = df_plot.reset_index(drop=True)
df_plot['percentage'] = df_plot.groupby(['source'], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

df_plot_ct = hh.groupby(['source','auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
    rename(columns={'hhexpfac':'sample count'})
df_plot = df_plot.merge(df_plot_ct, on=['source','auto_ownership_simple'], how='left')
df_plot = df_plot[df_plot['auto_ownership_simple'] != '-1']

fig = px.bar(df_plot.sort_values(by=['source']), x="auto_ownership_simple", y="percentage", color="source",
             hover_data=['sample count'],
             barmode="group",title="Auto ownership")
fig.update_layout(height=400, width=700, font=dict(size=11),
                  yaxis=dict(tickformat=".2%"))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="dce193d4-dcaa-486a-9337-030e4c20a4ff" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dce193d4-dcaa-486a-9337-030e4c20a4ff")) {                    Plotly.newPlot(                        "dce193d4-dcaa-486a-9337-030e4c20a4ff",                        [{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fw==","shape":"5, 1"},"hovertemplate":"source=ACS\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ACS","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"ACS","offsetgroup":"ACS","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,2,3,"4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"fa25WlYxtT96svw4NYfVPxiOrU9\u002fKdc\u002f2C9rVPl9wj+M8MbZ5A+zPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAIBH\u002f0AAAAAAtrQjQQAAAABsRyhBAAAAAHTiFEEAAAAAqEgGQQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"gTe21xuTsz+byuXJEuzUP8lOF92XXdc\u002ftf5bviJEwz+KZZ0P9L20Pw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"f8","bdata":"AAAAAAB4g0AAAAAAAKSZQAAAAAAA+JBAAAAAAACwcUAAAAAAAGBgQA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#00A7A0","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"pdAR0zGgtT+Not+TIZXUP0Grnx5sVtg\u002fTovUkvcHwT9\u002fZQA\u002fO4K0Pw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.33333333 ...

# %% [markdown]
# ## Auto ownership by segments

# %%
# auto ownership in Income groups
def plot_auto(df:pd.DataFrame, var:str, title_cat:str, sub_name:str):
    df2 = df.loc[df['auto_ownership_simple'] != '-1'].copy()
    df_plot = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].sum().reset_index()
    df_plot['percentage'] = df_plot.groupby(['source',var], group_keys=False)['hhexpfac'].\
        apply(lambda x: x / float(x.sum()))

    df_plot_ct = df2.groupby(['source',var,'auto_ownership_simple'])['hhexpfac'].count().reset_index(). \
        rename(columns={'hhexpfac':'sample count'})
    df_plot = df_plot.merge(df_plot_ct, on=['source',var,'auto_ownership_simple'])

    fig = px.bar(df_plot, x="auto_ownership_simple", y="percentage", color="source",
                 facet_col=var, barmode="group",
                 hover_data=['sample count'],
                 title="Auto ownership by "+ title_cat)
    fig.for_each_annotation(lambda a: a.update(text = sub_name + "=<br>" + a.text.split("=")[-1]))
    fig.update_xaxes(title_text="n of cars")
    fig.update_layout(height=400, width=800, font=dict(size=11),
                      yaxis=dict(tickformat=".2%"))
    fig.for_each_yaxis(lambda a: a.update(tickformat = ".2%"))
    fig.show()

# %% [raw]
# :::{.panel-tabset}
#
# ### income

# %%
plot_auto(hh,'hhincome_4group','income level', 'Income')
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:8: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3df90b29-0206-49ea-95f3-2cbc61282178" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3df90b29-0206-49ea-95f3-2cbc61282178")) {                    Plotly.newPlot(                        "3df90b29-0206-49ea-95f3-2cbc61282178",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"gUwBAFy4AwBWEgIAnKMAAN1DAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"oN43zzKByT\u002fyQdJ9697dPw2ltUNWHc4\u002fNu3BK1fksT+fDmjcooudPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"yU8AAOP\u002fAgBzFgMAhBMBAHuCAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"RD4JslFIqz8pb1MscEPaP7Ll+K\u002f609Y\u002f+v+lJnrhvj\u002fuGkgeYzmuPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"XjEAAEHfAQCZqAMAQ3gBAObOAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhincome_4group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"FJzjln1Ooz\u002f\u002f8GKeGJvRP6IMFl8gbds\u002fu\u002fIXLekFxT\u002f8VXrkCiy4Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"cQE0AgcBRwAkAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"YWNZAHrHyD\u002fA6BeMqoXZP2Ot3hhIqNE\u002fge2HCmsxtD9m5tXBrA+rPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"ewDFAeYANAAYAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"cJBvW3Z0pT\u002fPocXV60DaP3eO+HlPn9c\u002fPAKX2KosvT9sdLi6LJiwPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"PAAOAd0ANgAeAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhincome_4group=high\u003cbr\u0 ...

# %% [raw]
# ### household size

# %%
plot_auto(hh,'hhsize_simple','household size', 'HH size')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="07cb63fb-20c1-4595-8671-016837c2a92c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("07cb63fb-20c1-4595-8671-016837c2a92c")) {                    Plotly.newPlot(                        "07cb63fb-20c1-4595-8671-016837c2a92c",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"tlABAKqSBQBYBwEAXDwAAIAWAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"aTFPPE0cyD9UwvAa92blP+Q9YZsVRLw\u002fVzGRYEgEmD92ArDiJ1SCPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"k2AAAO16AgB\u002f3AUAQJYBAAd3AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"OJML10BZpz9S8zQWieXPP7wYJiXx8uA\u002fxivPFh5twT+0ZIIiEC2kPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"ex4AAM7XAACvMQIA5m4BAMCSAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"MdH57\u002faamz\u002fE1deqUojGPz9lAuAlRNs\u002fgRmShegV0T8x5f9XY6C6Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"tCQAAPb0AAAwDgMAG\u002fcBAM6oAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehhsize_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"6REJP+tPlD+WNISyZI7APzjulENSCtk\u002fBgJB4+F6zz+5yi97F1jLPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"6gGQA24AFgANAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"Nu4pF6CJzD\u002flNfcUrdnkP0yF1KIjHLU\u002f\u002foRvHS3mnT8CbxD+QU2MPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"bwADAlYCgAA0AA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehhsize_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003e ...

# %% [raw]
# ### number of drivers

# %%
plot_auto(hh.loc[hh['num_drivers_simple']!="0"],'num_drivers_simple','number of (poential) drivers age 16+','num drivers')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c7da11a3-bc01-45c7-a4f8-59b16422007b" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c7da11a3-bc01-45c7-a4f8-59b16422007b")) {                    Plotly.newPlot(                        "c7da11a3-bc01-45c7-a4f8-59b16422007b",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"vmUBAJsnBgDjJgEAfkIAAIsYAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"8UZSrdpUxz9KH3UtsIPlP6rMx23S6Lw\u002fRLawhSsYmD+p7PNTX0+CPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"JG4AAIolAwCDSQkAO2UCAHyiAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AcNOsY\u002fCoT9Ou0\u002fVJZ\u002fLP7arAhssP+I\u002f5VAj+Wc1wj\u002fMULpkd\u002fiiPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"+REAAC1iAAAcMAEAwNABAKm4AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"Kd6aySQrlj\u002f1pef68rG5P68iCRUwUtI\u002fw3KsCSI02z9apu2r\u002fVTFPw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"nQ4AAAkrAAA0gwAAJMAAAGVVAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_drivers_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"uoc5HW3qlD+RCF7TcZawPzaoD6QVVsc\u002fnYSH3NXW0D+mjMUK3AnePw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"8QG6A3cAFwAOAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_drivers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"td18JsIqzD+r1btd2qHkP0eu+aJCR7Y\u002fGzGi7Un9oT9Lg+ZaCa6KPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"cABoAlIDnwA4AA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_drivers_simple=2\u003cbr\u003eauto_ ...

# %% [raw]
# ### number of workers

# %%
plot_auto(hh,'num_workers_simple','number of workers','num workers')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="f7ec2bd7-8791-472d-87a3-2743cc06be4c" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f7ec2bd7-8791-472d-87a3-2743cc06be4c")) {                    Plotly.newPlot(                        "f7ec2bd7-8791-472d-87a3-2743cc06be4c",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"aRsBAOwqAwCxHAIAZNYAAKdEAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=0\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"dGa53T7Ixj8mwycPdUnbP07BN8sq6tA\u002fQWk9U0yZuT8PcKMPbQ+gPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"zLEAALAcBQCQhAQAeZYBAPOoAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=1\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"hk6NlBUksz+VcI0sO+XbP83HdwD3G9U\u002fGrrb0QfovD+cKwTLM96nPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"LyQAAHN1AQAcJwUAASwCAAoHAQA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=2\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"BYIjMkGGlD\u002fGFwgOY17FP\u002f7nbtxfduA\u002f\u002ff741Hgqyj8Gsv0JuRm4Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"RgJ1Eks4fWkkcQ==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=3\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"V1KHrlW0hT\u002fGKuCkQbGyP0vDbOf\u002fbck\u002fVxh8JX3G1T\u002fBQCHQjyjYPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"zgDXCg4jQjZNYw==","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003enum_workers_simple=4+\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x5","y":{"dtype":"f8","bdata":"Q73iYqzscz\u002fAVzyjUIevP9fVchJQMMc\u002fyvcuYJ0s0T9gh6TQnfrePw=="},"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"4gCcAesATAAbAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003enum_workers_simple=0\u003cbr\u003eauto_ownership_sim ...

# %% [raw]
# ### household density

# %%
plot_auto(hh.dropna(subset=['hh_density_group']),'hh_density_group','household density','density')
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:8: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0a9beb60-4d5b-456c-b50e-5540b6170b65" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0a9beb60-4d5b-456c-b50e-5540b6170b65")) {                    Plotly.newPlot(                        "0a9beb60-4d5b-456c-b50e-5540b6170b65",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"kgYAAP+eAABUnQEACCQBALeXAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"pTvAdgGOej+lNUhibbrCP32PCuHmDNo\u002fnnhU+9Z10j9EuEPZpmvDPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"jA4AAGXRAABbtQEASuoAAOB+AAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"C2DWptTEiz+EIUYLYejIP6NTxicorNs\u002fdqXsxXbvzT\u002fDK9OUihPAPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"\u002fDUAABkQAgCtZQMAqX8BAJrRAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh_density_group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"pWZezT3\u002fmD\u002flpReUZ9XPPx8R1gxAiNs\u002fnXaSC\u002fZuyD\u002fa6PsZdRa7Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"knQAAPPNAgAtEwMA7hIBAImUAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003ehh_density_group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"V2CNZGQkqj\u002f1S5ND+xLWP5JYq6oc\u002fNg\u002fum8+2GyowT9I3kFklGCzPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"WQD6ALMAOQAWAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehh_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"+heKmNomuj9Ip+32Z\u002f3VP88z0aiVYNU\u002fzlW0miT9wz8G0BGz5WawPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"RwDvAJsANgAYAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003ehh_density_group ...

# %% [raw]
# ### employment density

# %%
plot_auto(hh.dropna(subset=['emp_density_group']),'emp_density_group','employment density','density')
# Out:
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\aditya.gore\AppData\Local\Temp\7\ipykernel_407416\851578008.py:8: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="93798041-66f8-4891-9e50-34746650374f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("93798041-66f8-4891-9e50-34746650374f")) {                    Plotly.newPlot(                        "93798041-66f8-4891-9e50-34746650374f",                        [{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"xQwAAHLEAABQOgIACh8BAHGSAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eemp_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"rFt8XVkbhD8buAG2yULEP0ByR8Fwnt0\u002f\u002fyItuJwQzz+oemp5Ai7APw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"7QgAAOKWAAAJaQEA+MoAAERsAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eemp_density_group=low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x2","y":{"dtype":"f8","bdata":"HhWTXQ8hiT+RRtP5pYvHPwxoIII29Ns\u002fSJGOLiKYzj+\u002fJoTduWHAPw=="},"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"Ii4AACQDAgCDWwMAT5QBAAncAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eemp_density_group=medium\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x3","y":{"dtype":"f8","bdata":"L8KYhMDDlj+FO83B6y\u002fQP8P53yNcBds\u002f0fM\u002fngrmyD+vEqUL2627Pw=="},"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i4","bdata":"iXQAAIrdAgAb+QIA5xcBAOKZAAA=","shape":"5, 1"},"hovertemplate":"source=model\u003cbr\u003eemp_density_group=high\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"model","marker":{"color":"#91268F","pattern":{"shape":""}},"name":"model","offsetgroup":"model","orientation":"v","showlegend":false,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x4","y":{"dtype":"f8","bdata":"Y36u3RlFqz9a7WnmkrfWP+HieIglNNg\u002fMAGuIDiNwT+IfUEUIZSzPw=="},"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i2","bdata":"pACXARIBPQAhAA==","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003eemp_density_group=very low\u003cbr\u003eauto_ownership_simple=%{x}\u003cbr\u003epercentage=%{y}\u003cbr\u003esample count=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"survey","marker":{"color":"#8CC63E","pattern":{"shape":""}},"name":"survey","offsetgroup":"survey","orientation":"v","showlegend":true,"textposition":"auto","x":["0","1","2","3","4+"],"xaxis":"x","y":{"dtype":"f8","bdata":"hW2nkByltz9f5XT\u002fjOHSP74q5O9Q2dk\u002f9Eh85aHLwD8fwPvmJ9izPw=="},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":{"dtype":"i1","bdata":"IVlMGhA=","shape":"5, 1"},"hovertemplate":"source=survey\u003cbr\u003eemp_density_group=low\u003cbr\u003eauto ...

# %% [raw]
# :::

# %% [markdown]
# ## Validate auto ownership with ACS vehicle ownership data

# %%
df_acs
# Out:
#   auto_ownership_simple       hhexpfac source
# 0                     0  143723.838187    ACS
# 1                     1  583994.620470    ACS
# 2                     2  628318.617840    ACS
# 3                     3  250817.549140    ACS
# 4                    4+  129274.374393    ACS

# %%
# ACS auto ownership validation dataset
df_acs = pd.read_sql(text("SELECT * FROM bg_auto_ownership"), con=conn.connect())
maz_bg_lookup = pd.read_sql(text("SELECT * FROM maz_bg_lookup"), con=conn.connect())

# add lookup for maz and block groups
df_acs = df_acs.merge(maz_bg_lookup, on='block_group_id')
df_acs_taz = df_acs[['TAZ','block_group_id','cars_none_control', 'cars_one_control','cars_two_or_more_control']].drop_duplicates()

hh_taz = hh.merge(df_acs_taz, how='left', left_on='hhtaz', right_on='TAZ')

# %%
df = hh_taz.groupby(['source','block_group_id','auto_ownership_2'])['hhexpfac'].sum().reset_index()

df['percentage'] = df.groupby(['source','block_group_id'], group_keys=False)['hhexpfac'].\
    apply(lambda x: 100 * x / float(x.sum()))

# acs auto ownership data
acs_auto_ownership = pd.read_sql(text("SELECT cars_none_control, cars_one_control, cars_two_or_more_control, block_group_id FROM bg_auto_ownership"), 
                                 con=conn.connect())
# acs_auto_ownership = pd.read_csv(config['p_acs_auto_ownership'], usecols=['cars_none_control', 'cars_one_control', 'cars_two_or_more_control', 'block_group_id'])

# calculate percentage of households having 0, 1 or 2+ vehicle(s) in each block group
acs_auto_ownership['total'] = acs_auto_ownership['cars_one_control'] + acs_auto_ownership['cars_two_or_more_control'] + acs_auto_ownership['cars_none_control']
acs_auto_ownership['0'] = 100 * acs_auto_ownership['cars_none_control']/acs_auto_ownership['total']
acs_auto_ownership['1'] = 100 * acs_auto_ownership['cars_one_control']/acs_auto_ownership['total']
acs_auto_ownership['2+'] = 100 * acs_auto_ownership['cars_two_or_more_control']/acs_auto_ownership['total']
acs_auto_ownership['source'] = "acs data"
bg_auto_ownership = acs_auto_ownership[['source','block_group_id','0','1','2+']]
bg_auto_ownership = pd.melt(bg_auto_ownership, id_vars=['source','block_group_id'], value_vars=['0','1','2+'], var_name='auto_ownership_2',value_name='percentage')

# combine both sets of data
col_list = ['source','block_group_id','auto_ownership_2','percentage']
bg_auto_ownership = pd.concat([df[col_list].copy(),
                               bg_auto_ownership[col_list].copy()])

# %%
df_plot = pd.pivot(bg_auto_ownership, index=['block_group_id','auto_ownership_2'], columns='source', values='percentage').reset_index()



fig = px.scatter(df_plot, x="acs data", y="model", trendline="ols", trendline_color_override='rgb(136, 136, 136)',
                 template="plotly_white",
                 facet_col='auto_ownership_2', height=400, width=1000,
                 title="Auto ownership model results validation with acs data")
fig.update_xaxes(dtick=20)
fig.update_yaxes(dtick=20,range=[0, 100])
fig.update_traces(marker_size=3)
fig.update_layout(height=400, width=950, font=dict(size=11))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="97e21ba6-1321-4434-88e0-066f8ae8b0e4" class="plotly-graph-div" style="height:400px; width:950px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("97e21ba6-1321-4434-88e0-066f8ae8b0e4")) {                    Plotly.newPlot(                        "97e21ba6-1321-4434-88e0-066f8ae8b0e4",                        [{"hovertemplate":"auto_ownership_2=0\u003cbr\u003eacs data=%{x}\u003cbr\u003emodel=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"UscDRMgUMkAvuuiiiy4yQMVbrjGrKzJApnEDo840MkBfEQKx\u002fBcyQJOVrGQlKxlAZeDp1vywGECTlaxkJSsZQKL0gqDl3RhASpMmTZo0GUAAAAAAAAAZQD1pG1hkeRhATHxf1PJvGEDO24qJI8I5QMcw2QKI3jlA7aNoGWu4OUAHN\u002fuFWFEyQNgeclkxUDJAPPb0bYcTMkCXPZZL2zkyQMAf8Af8Af8\u002foRYwJnHw\u002fj\u002fAIkrAIkoAQHCpbO86oCFADdIgDdKgIUBELisGSnghQJZ7GmG5pyFAa6211lprIUAhBSyPN7IhQJrTLnT+gChAMEU+6wZTKEAmS7cc+1coQPwI7iO4jyhAKK+hvIby+j\u002f7RZHcJ3P+P8JyTyMs9wJAyiDywFW0A0De9XylsRsVQMog8sBVtBNAFLQDOC8KGkBCGqRBGqQZQJ3dwq\u002fGRDVAvoT2EtpLNUDB2NdcgTg1QJjmLvirODVAAAAAAABANUBzwy4WkSorQCAYki2iOStAKcYPcOE2K0DAH\u002fAH\u002fAEfQMfFAkktUx5AT+zETuzEHkBpz8sTdO4eQCVJkiRJkgxAS8oBkeFeDUDPepBAl1cSQNSvF9ZdgRJA0UQTTTTREkDGp0w7B2syQLIuGJFmZzJACqVQCqVQMkD1mL\u002fXRqwrQJh4P3KarytAJbzR1Pm1K0AgGJItojkrQPJUxlMZTxVAo6nzaw+5FED6GJyPwfkUQF4pMQrN\u002filA0WAm+PXkKUALRn4ASTQqQLqD\u002fVYbQyBA7l\u002fd\u002ftXtH0B2gynyWTcgQE\u002fsxE7sxA5AYOsKze1UDkBZU9aUNWUPQAxXYamhaxFALSkHRIZ7EUCE3ZKaVXsQQOj9Y5kjXBBA3xWZL00cBkCP7BmISkcGQMamk8WmkwVAoVSYeD9yGkC\u002fupAWyyMaQC8eARNDdBhARCG5gNfbGEDHhVSR\u002fbMYQAGRAkQKEBlAx\\u002fhu4yVAT+zETuzEHkBjhjQFuQ0fQD7x+MTjEx9A+N577733HkDdFSj0FFEfQBV2TXIJqhRAYwjZeN0JFEBVVVVVVdUUQNu2bdu2bSVAgtaiUB9oJUA22WSTTTYlQPiQolTS7i5AyRCso837LkCN3y71ZPwuQArXo3A9Ci9AT31R7vLUH0CcqVdyBMMfQJUG79rYmhtAsGk\u002fWQKbGkBNd7DfamMkQJtssskmmyRA1Xyf7AsgBkCOAQ5+buIFQKjioDVnIgZAj10NSy\u002fiBEAg0QqbA4kGQPQxOB+D8wVAJ5xwwgknDECytzZMcxcMQLbUVbsD\u002fQtA1NfRc\u002fcLDEBhpq4U\u002f0kLQBtXjhpXjipAq6qqqqqqKkADLdACLdAqQOA96j+EK0hA8bV4V+YzSEALz4\u002fpYeA+QCYh3\u002flZyz5Ao6nzaw+5PkBx5nUqXdY+QG\u002fV1NfIEyVAPc\u002fzPM\u002fzJEAZ8MnhMuADQHLDvIyD4QRAxBzmMIc5BEDYBsGpTNgwQNFuk\u002fkj0DBAWN6SUEPaMEBsjLbTrOAwQDIN283yJBJA032uQVYqE0DCck8jLPcSQP7z9HoAwxJAXBq+JKTlKUDHMNkCiN4pQHBMm4BS1ClA0LrBFPmsKUAaSI0MCcUpQAouIqH3sypAObjZL8SKKkANmd6B\u002fa0qQJcBnxwuAyJAy+pd8mDAIUCmpaWlpaUhQPdVkUpZDEBALVcy7vzkP0BnBYcvpAhAQEXm0MNd2z9Aep7neZ7nP0A4velNb3pMQFkgkq51Z0xAwHQireB5TECJ5+yfRGFMQAAAAAAAAE5AAAAAAAAATkAAAAAAAAD4\u002f3FH3BF3xCNALMKWz5e7I0B8vMd7vMcjQH5Xi5swvyNAFm2slD3+BUAW\u002fBfNN2oFQAAAAAAA4AVA9IftS+RxBkAermUO4H4GQJAGaZAGaQBAgbKOqyFfAkCQwfkYnI8BQD\u002fiXdMMPQNAD+jGPH20AkDT0tLS0tICQLaErxmmuiJAbbLJJptsIkDmqS\u002fKXZ4iQIyHuBeNSiJA0Q9Q5Qj9IECBHyP1iUEhQEyRz7rBFCFAigdNKQolG0CzMRuzMRsbQDaU11BeQxlAMpEeqJzdGkAbV44aV44aQAAAAAAAQBVAEvLob3vDFUDfz1PG0mQVQDOs1ltQhhVA4qz8hDgrH0BP7MRO7MQeQM6\u002f5OebHR9Aot9sHfrNHkCZjThtE+MCQMxQeKICNgNAcucnX0UvA0AGWsWHiXMWQGZI+Z5NKBZAy2ksp7GcFkBoPOMZz3gWQD744IMPPhhAZjwIpK2XF0A4velNb3oXQKV9kAyoZzJAk3cS8DB8MkDqxXzqxXwyQOgAfyduIDFAVNhy6f0gMUAT17mHn1owQMYhCoNaTjBAqXRkz0BUMED6pV\u002f6pV8wQCELWchCFipADJTbmuEzKkBfypjdScMTQJybm5ubmxNAg\u002fMxOB+DE0Cn8UBuGg8UQAZ9QV\ ...
