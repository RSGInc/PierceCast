# %%
import os, sys, time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
pd.options.mode.chained_assignment = None
import h5py

# %matplotlib inline

from IPython.display import display, HTML

if (sys.version_info < (3, 0)):
    HTML('''<script>
    code_show=true; 
    function code_toggle() {
     if (code_show){
     $('div.input').hide();
     } else {
     $('div.input').show();
     }
     code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
# Create timestamp to show when this summary was run
print('Summary run: ' + time.strftime("%a, %d %b %Y %H:%M:%S"))
# Out:
# Summary run: Thu, 23 Dec 2021 15:06:03

# %%
pd.options.display.float_format = '{:0,.0f}'.format

# %%
# Region
# Counties
# RGC
# MIC
# HCT Areas
# Regional Geographies
# Equity Geographies (over 50%)
# Equity Geographies (over Regional Average)


# Travel Metrics
# Transit Ridership
# Congestion Levels
# Truck Data
# VMT
# Delay
# Miles of Congestion
# Vehicle Data
# VMT
# Delay
# Miles of Congestion

# %%
geog = 'rgc'
geog_col = 'hh_rgc'

# %% [markdown]
# # Regional Growth Center
# Results based on household location

# %% [markdown]
# # Population

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_geog.csv')
_df_pop = df.groupby(geog_col).sum()[['psexpfac']]

df = pd.read_csv(r'..\..\..\outputs\agg\dash\hh_geog.csv')
_df_hh = df.groupby(geog_col).sum()[['hhexpfac']]

df = _df_hh.merge(_df_pop, on=geog_col)
df.rename(columns={'hhexpfac': 'Households', 'psexpfac': 'Persons'}, inplace=True)
df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'1_population.csv'))
df.loc['Total'] = df.sum(axis=0)
df
# Out:
#                                  Households   Persons
# hh_rgc
# Auburn                                  650     1,406
# Ballard-Interbay                        243       391
# Bellevue                              8,239    14,209
# Bothell Canyon Park                     201       466
# Bremerton                             1,262     2,556
# Burien                                1,759     3,449
# Cascade                                 407     1,233
# Duwamish                                621     1,119
# Everett                               3,457     6,199
# Frederickson                            200       607
# Kent                                    721     1,563
# Kent MIC                                100       259
# Kirkland Totem Lake                   2,811     5,202
# Lakewood                              1,193     2,699
# Lynnwood                              1,521     3,430
# North Tukwila                            10        26
# Not in RGC                        1,472,234 3,823,656
# Paine Field / Boeing Everett            200       533
# Port of Tacoma                            2         2
# Puyallup Downtown                       694     1,386
# Puyallup South Hill                     729     1,472
# Redmond Downtown                      3,451     6,797
# Redmond-Overlake                      1,106     2,323
# Renton                                3,059     5,505
# SeaTac                                4,266    10,659
# Seattle Downtown                     23,886    35,918
# Seattle First Hill/Capitol Hill      30,749    48,121
# Seattle Northgate                     4,569     8,299
# Seattle South Lake Union              8,683    13,663
# Seattle University Community         10,071    19,052
# Seattle Uptown                        6,976    10,644
# Silverdale                            1,114     2,071
# Sumner Pacific                           27        69
# Tacoma Downtown                       7,813    13,178
# Tacoma Mall                           2,174     4,847
# Tukwila                                  65       145
# Total                             1,605,263 4,053,154

# %% [markdown]
# # Employment

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_geog.csv')
df = df[df['pwtyp'].isin(['Paid Full-Time Worker', 'Paid Part-Time Worker'])]
_df = df.pivot_table(index=geog_col, columns='pwtyp', aggfunc='sum', values='psexpfac')
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'2_employment.csv'))
_df.loc['Total'] = _df.sum(axis=0)
_df['Total'] = _df.sum(axis=1)
_df
# Out:
# pwtyp                            Paid Full-Time Worker  Paid Part-Time Worker  \
# hh_rgc
# Auburn                                             499                    108
# Ballard-Interbay                                   262                     25
# Bellevue                                         7,863                    812
# Bothell Canyon Park                                275                     29
# Bremerton                                          989                    269
# Burien                                           1,521                    435
# Cascade                                            459                    113
# Duwamish                                           540                    112
# Everett                                          2,618                    449
# Frederickson                                       234                     47
# Kent                                               451                     89
# Kent MIC                                            84                     13
# Kirkland Totem Lake                              2,534                    686
# Lakewood                                           876                    284
# Lynnwood                                         1,327                    352
# North Tukwila                                        9                      1
# Not in RGC                                   1,495,449                349,038
# Paine Field / Boeing Everett                       207                     56
# Port of Tacoma                                       1                    NaN
# Puyallup Downtown                                  548                    138
# Puyallup South Hill                                577                    140
# Redmond Downtown                                 3,670                    499
# Redmond-Overlake                                 1,095                    201
# Renton                                           2,722                    339
# SeaTac                                           4,282                    854
# Seattle Downtown                                20,549                  2,944
# Seattle First Hill/Capitol Hill                 27,899                  4,702
# Seattle Northgate                                3,309                    944
# Seattle South Lake Union                         9,021                    636
# Seattle University Community                     5,584                  4,232
# Seattle Uptown                                   6,961                    936
# Silverdale                                         859                    176
# Sumner Pacific                                      21                      3
# Tacoma Downtown                                  5,263                  1,255
# Tacoma Mall                                      2,027                    544
# Tukwila                                             74                      8
# Total                                        1,610,659                371,469
#
# pwtyp                               Total
# hh_rgc
# Auburn                                607
# Ballard-Interbay                      287
# Bellevue                            8,675
# Bothell Canyon Park                   304
# Bremerton                           1,258
# Burien                              1,956
# Cascade                               572
# Duwamish                              652
# Everett                             3,067
# Frederickson                          281
# Kent                                  540
# Kent MIC                               97
# Kirkland Totem Lake                 3,220
# Lakewood                            1,160
# Lynnwood                            1,679
# North Tukwila                          10
# Not in RGC                      1,844,487
# Paine Field / Boeing Everett          263
# Port of Tacoma                          1
# Puyallup Downtown                     686
# Puyallup South Hill                   717
# Redmond Downtown                    4,169
# Redmond-Overlake                    1,296
# Renton                              3,061
# SeaTac                              5,136
# Seattle Downtown                   23,493
# Seattle First Hill/Capitol Hill    32,601
# Seattle Northgate                   4,253
# Seattle South Lake Union            9,657
# Seattle University Community        9,816
# Seattle Uptown                      7,897
# Silverdale                          1,035
# Sumner Pacific                         24
# Tacoma Downtown                     6,518
# Tacoma Mall                         2,571
# Tukwila                                82
# Total                           1,982,128

# %% [markdown]
# ### Transit Ridership
#
# #### Total trips

# %%
# Region
# By Agency

# Transit Trips from Daysim, by location
df = pd.read_csv(r'..\..\..\outputs\agg\dash\mode_share_'+geog+'.csv')
_df = df[df['mode']=='Transit'].groupby(geog_col).sum()[['trexpfac']]
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'3_transit_trips.csv'))
_df.loc['Total'] = _df.sum(axis=0)
_df
# Out:
#                                  trexpfac
# hh_rgc
# Auburn                                313
# Ballard-Interbay                      128
# Bellevue                            2,707
# Bothell Canyon Park                    47
# Bremerton                             260
# Burien                                793
# Cascade                                48
# Duwamish                              486
# Everett                               465
# Frederickson                           13
# Kent                                  420
# Kent MIC                               49
# Kirkland Totem Lake                   704
# Lakewood                              122
# Lynnwood                              341
# North Tukwila                           3
# Not in RGC                        407,861
# Paine Field / Boeing Everett           41
# Port of Tacoma                          4
# Puyallup Downtown                     213
# Puyallup South Hill                   174
# Redmond Downtown                    1,085
# Redmond-Overlake                      346
# Renton                                958
# SeaTac                              3,705
# Seattle Downtown                   14,162
# Seattle First Hill/Capitol Hill    23,252
# Seattle Northgate                   2,552
# Seattle South Lake Union            4,213
# Seattle University Community        8,546
# Seattle Uptown                      3,680
# Silverdale                             81
# Sumner Pacific                          4
# Tacoma Downtown                     1,916
# Tacoma Mall                           662
# Tukwila                                54
# Total                             480,408

# %% [markdown]
# #### % Commute Trips by Transit (Home to Work direct)

# %%
# Mode share
df = df[df['dpurp'] == 'Work']
_df = df.pivot_table(index=[geog_col, 'mode'], aggfunc='sum', values='trexpfac').reset_index()
_df_tot = _df.groupby(geog_col).sum()[['trexpfac']]
_df = _df.merge(_df_tot, how='left', on=geog_col)
_df['mode_share'] = _df['trexpfac_x']/_df['trexpfac_y']

_df = _df[_df['mode'] == 'Transit'][[geog_col,'mode_share']]
pd.options.display.float_format = '{:0,.1%}'.format
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'4_transit_commute_share.csv'))
_df
# Out:
#                               hh_rgc  mode_share
# 5                             Auburn       16.4%
# 12                  Ballard-Interbay       10.4%
# 19                          Bellevue        5.5%
# 26               Bothell Canyon Park        5.8%
# 33                         Bremerton        6.3%
# 40                            Burien        8.2%
# 47                           Cascade        3.1%
# 54                          Duwamish       10.4%
# 62                           Everett        4.2%
# 68                      Frederickson        2.7%
# 75                              Kent       18.6%
# 81                          Kent MIC       13.9%
# 88               Kirkland Totem Lake        5.1%
# 95                          Lakewood        4.5%
# 102                         Lynnwood        5.7%
# 112                       Not in RGC        6.0%
# 119     Paine Field / Boeing Everett        5.1%
# 122                   Port of Tacoma       25.0%
# 129                Puyallup Downtown       12.8%
# 136              Puyallup South Hill        9.3%
# 143                 Redmond Downtown        6.1%
# 151                 Redmond-Overlake        6.0%
# 158                           Renton        5.6%
# 165                           SeaTac       16.0%
# 173                 Seattle Downtown        6.3%
# 180  Seattle First Hill/Capitol Hill       11.3%
# 187                Seattle Northgate       11.0%
# 194         Seattle South Lake Union        5.9%
# 201     Seattle University Community       13.0%
# 209                   Seattle Uptown        7.8%
# 216                       Silverdale        2.2%
# 221                   Sumner Pacific        3.8%
# 229                  Tacoma Downtown        7.2%
# 236                      Tacoma Mall        8.9%
# 243                          Tukwila       23.0%

# %% [markdown]
# ## VMT

# %%
pd.options.display.float_format = '{:0,.0f}'.format
# aggfunc sum trips filtered by dorp==1 and auto modes | groupby hh_rg_proposed
# hh_rg_proposed, 
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_vmt.csv')
df = df[(df['dorp'] == 1) & (df['mode'].isin(['SOV','HOV2','HOV3+']))]
_df = df.groupby(geog_col).sum()[['travdist_wt']]
_df['% of VMT'] = (_df/_df.sum()).astype('float')
_df.rename(columns={'travdist_wt': 'VMT'}, inplace=True)
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'5_vmt.csv'))
_df[['VMT']].plot(kind='barh', alpha=0.6)
_df.loc['Total'] = _df.sum(axis=0)
_df['% of VMT'] = _df['% of VMT'].apply('{:0,.1%}'.format)
_df
# Out:
#                                        VMT % of VMT
# hh_rgc
# Auburn                              17,638     0.0%
# Ballard-Interbay                     4,030     0.0%
# Bellevue                           101,774     0.1%
# Bothell Canyon Park                  9,307     0.0%
# Bremerton                           13,252     0.0%
# Burien                              47,540     0.1%
# Cascade                             21,711     0.0%
# Duwamish                            12,468     0.0%
# Everett                             56,398     0.1%
# Frederickson                        11,696     0.0%
# Kent                                15,765     0.0%
# Kent MIC                             2,366     0.0%
# Kirkland Totem Lake                 80,451     0.1%
# Lakewood                            25,520     0.0%
# Lynnwood                            45,904     0.1%
# North Tukwila                          246     0.0%
# Not in RGC                      67,301,484    97.6%
# Paine Field / Boeing Everett         7,989     0.0%
# Port of Tacoma                          16     0.0%
# Puyallup Downtown                   16,465     0.0%
# Puyallup South Hill                 21,117     0.0%
# Redmond Downtown                    80,668     0.1%
# Redmond-Overlake                    23,046     0.0%
# Renton                              75,847     0.1%
# SeaTac                             132,832     0.2%
# Seattle Downtown                    96,741     0.1%
# Seattle First Hill/Capitol Hill    198,340     0.3%
# Seattle Northgate                   83,488     0.1%
# Seattle South Lake Union            62,265     0.1%
# Seattle University Community       126,414     0.2%
# Seattle Uptown                      64,988     0.1%
# Silverdale                          17,970     0.0%
# Sumner Pacific                         972     0.0%
# Tacoma Downtown                    109,844     0.2%
# Tacoma Mall                         52,020     0.1%
# Tukwila                              1,279     0.0%
# Total                           68,939,851   100.0%

# %%
pd.options.display.float_format = '{:0,.0f}'.format
# aggfunc sum trips filtered by dorp==1 and auto modes | groupby hh_rg_proposed
# hh_rg_proposed, 
df = pd.read_csv(r'..\..\..\outputs\agg\dash\person_vht.csv')
df = df[(df['dorp'] == 1) & (df['mode'].isin(['SOV','HOV2','HOV3+']))]
_df = df.groupby(geog_col).sum()[['travtime_wt']]/60.0
_df['% of VHT'] = (_df/_df.sum()).astype('float')
_df.rename(columns={'travtime_wt': 'VHT'}, inplace=True)
_df[['VHT']].plot(kind='barh', alpha=0.6)
_df.loc['Total'] = _df.sum(axis=0)
_df['% of VHT'] = _df['% of VHT'].apply('{:0,.1%}'.format)
_df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'6_vht.csv'))
_df
# Out:
#                                       VHT % of VHT
# hh_rgc
# Auburn                                717     0.0%
# Ballard-Interbay                      232     0.0%
# Bellevue                            4,812     0.2%
# Bothell Canyon Park                   375     0.0%
# Bremerton                             825     0.0%
# Burien                              1,902     0.1%
# Cascade                               756     0.0%
# Duwamish                              683     0.0%
# Everett                             2,483     0.1%
# Frederickson                          469     0.0%
# Kent                                  629     0.0%
# Kent MIC                              100     0.0%
# Kirkland Totem Lake                 3,352     0.1%
# Lakewood                            1,130     0.0%
# Lynnwood                            2,075     0.1%
# North Tukwila                          12     0.0%
# Not in RGC                      2,725,470    96.9%
# Paine Field / Boeing Everett          317     0.0%
# Port of Tacoma                          1     0.0%
# Puyallup Downtown                     693     0.0%
# Puyallup South Hill                   836     0.0%
# Redmond Downtown                    3,330     0.1%
# Redmond-Overlake                    1,008     0.0%
# Renton                              3,290     0.1%
# SeaTac                              5,850     0.2%
# Seattle Downtown                    7,387     0.3%
# Seattle First Hill/Capitol Hill    13,745     0.5%
# Seattle Northgate                   4,131     0.1%
# Seattle South Lake Union            4,468     0.2%
# Seattle University Community        6,950     0.2%
# Seattle Uptown                      4,450     0.2%
# Silverdale                            706     0.0%
# Sumner Pacific                         38     0.0%
# Tacoma Downtown                     5,860     0.2%
# Tacoma Mall                         2,410     0.1%
# Tukwila                                51     0.0%
# Total                           2,811,546   100.0%

# %% [markdown]
# ## Delay
# Calculated based on Household Location

# %%
# might need to be calculated individually?
# create a delay summary from total vmt and total sov_ff_time

# %%
df = pd.read_csv(r'..\..\..\outputs\agg\dash\trip_time_total.csv')
df = df.groupby(geog_col).sum()[['travtime_wt']]

df2 = pd.read_csv(r'..\..\..\outputs\agg\dash\trip_sov_ff_time.csv')
df2 = df2.groupby(geog_col).sum()[['sov_ff_time_wt']]
df = df2.merge(df, on=geog_col)

# Hours of delay from travel time (in min)
df['Total Delay Hours'] = (df['travtime_wt'] - df['sov_ff_time_wt'])/60

pd.options.display.float_format = '{:0,.0f}'.format
# Hours of delay for households in these locations
df[['Total Delay Hours']]

_df
# Out:
#                                       VHT % of VHT
# hh_rgc
# Auburn                                717     0.0%
# Ballard-Interbay                      232     0.0%
# Bellevue                            4,812     0.2%
# Bothell Canyon Park                   375     0.0%
# Bremerton                             825     0.0%
# Burien                              1,902     0.1%
# Cascade                               756     0.0%
# Duwamish                              683     0.0%
# Everett                             2,483     0.1%
# Frederickson                          469     0.0%
# Kent                                  629     0.0%
# Kent MIC                              100     0.0%
# Kirkland Totem Lake                 3,352     0.1%
# Lakewood                            1,130     0.0%
# Lynnwood                            2,075     0.1%
# North Tukwila                          12     0.0%
# Not in RGC                      2,725,470    96.9%
# Paine Field / Boeing Everett          317     0.0%
# Port of Tacoma                          1     0.0%
# Puyallup Downtown                     693     0.0%
# Puyallup South Hill                   836     0.0%
# Redmond Downtown                    3,330     0.1%
# Redmond-Overlake                    1,008     0.0%
# Renton                              3,290     0.1%
# SeaTac                              5,850     0.2%
# Seattle Downtown                    7,387     0.3%
# Seattle First Hill/Capitol Hill    13,745     0.5%
# Seattle Northgate                   4,131     0.1%
# Seattle South Lake Union            4,468     0.2%
# Seattle University Community        6,950     0.2%
# Seattle Uptown                      4,450     0.2%
# Silverdale                            706     0.0%
# Sumner Pacific                         38     0.0%
# Tacoma Downtown                     5,860     0.2%
# Tacoma Mall                         2,410     0.1%
# Tukwila                                51     0.0%
# Total                           2,811,546   100.0%

# %% [markdown]
# #### Average Delay Minutes per Household (per Weekday)

# %%
# Average minutes of delay per household
pd.options.display.float_format = '{:0,.1f}'.format
_df = _df_hh.merge(df[['Total Delay Hours']], left_index=True, right_index=True)
df['Avg. Minutes of Delay per Household'] = df['Total Delay Hours']/_df['hhexpfac']*60
df.to_csv(os.path.join(os.getcwd(), r'..\..\..\outputs\compare',geog,'7_delay.csv'))

df[['Avg. Minutes of Delay per Household']]
# Out:
#                                  Avg. Minutes of Delay per Household
# hh_rgc
# Auburn                                                           6.9
# Ballard-Interbay                                                 6.0
# Bellevue                                                         4.0
# Bothell Canyon Park                                             23.0
# Bremerton                                                       -0.3
# Burien                                                           6.4
# Cascade                                                         12.6
# Duwamish                                                         6.7
# Everett                                                          4.4
# Frederickson                                                    18.7
# Kent                                                             6.2
# Kent MIC                                                         5.7
# Kirkland Totem Lake                                             13.2
# Lakewood                                                         4.8
# Lynnwood                                                        13.6
# North Tukwila                                                    3.7
# Not in RGC                                                      13.4
# Paine Field / Boeing Everett                                    15.2
# Port of Tacoma                                                   0.2
# Puyallup Downtown                                                7.9
# Puyallup South Hill                                              9.7
# Redmond Downtown                                                 7.4
# Redmond-Overlake                                                 7.1
# Renton                                                           9.1
# SeaTac                                                           8.3
# Seattle Downtown                                                 0.4
# Seattle First Hill/Capitol Hill                                  1.5
# Seattle Northgate                                                6.7
# Seattle South Lake Union                                         1.8
# Seattle University Community                                     4.5
# Seattle Uptown                                                   2.4
# Silverdale                                                       0.5
# Sumner Pacific                                                  12.1
# Tacoma Downtown                                                  3.4
# Tacoma Mall                                                      7.2
# Tukwila                                                          6.2
